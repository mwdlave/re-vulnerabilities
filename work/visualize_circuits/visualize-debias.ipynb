# %% [markdown]
# # Evaluate circuit faithfulness

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import matplotlib.pyplot as plt
from transformer_lens import HookedTransformer
from src.graph import Graph

# def display_name(task):
#     if '-comma' in task:
#         task = task[:-6]
#     return display_name_dict[task]

def n_edges(model_name: str) -> int:
    model = HookedTransformer.from_pretrained(
        model_name,
        center_writing_weights=False,
        center_unembed=False,
        fold_ln=False,
    )
    model.cfg.use_split_qkv_input = True
    model.cfg.use_attn_result = True
    model.cfg.use_hook_mlp_in = True
    model.cfg.ungroup_grouped_query_attention = True
    g = Graph.from_model(model)
    return len(g.edges)

model_name = "meta-llama/Llama-3.2-1B"
model_name_noslash = 'Llama-3.2-1B-Instruct'
total_edges = n_edges(model_name)
print(f"Total number of edges: {total_edges}")

# %%
import plotly.subplots as sp
import plotly.graph_objects as go
import pandas as pd
import os

task_names = ['temp_toxicity_samp', 'adv-bias-3']
param_dict = {'temp_toxicity_samp': ['Toxicity', ['EAP', 'EAP-IG']],
                     'adv-bias-3': ['Name Bias', ['EAP', 'EAP-IG', 'EAP-IG-KL']]}

trace_colors = {
    'EAP': '#FFA15A', 
    'EAP-IG': '#19D3F3',
    'EAP-IG-KL': '#FF6692'
}

rows = 1
cols = len(task_names)
fig = sp.make_subplots(rows=rows, cols=cols, subplot_titles=[param_dict[task][0] for task in task_names])

# Iterate over tasks and add traces
for idx, task_name in enumerate(task_names):
    df = pd.read_csv(f'./inputs/{task_name}.csv')
    
    # Normalize faithfulness
    for losstype in param_dict[task_name][1]:
        df[f'normalized_faithfulness_{losstype}'] = (
            df[f'loss_{losstype}'] - df['corrupted_baseline']
        ) / (df['baseline'] - df['corrupted_baseline'])

    # Save processed data
    df.to_csv(f'./outputs/{task_name}_graph.csv', index=False)

    # Determine subplot position
    row = idx // cols + 1
    col = idx % cols + 1

    # Add traces with legend grouping
    show_legend = idx == 1  # Show legend only for the first subplot
    for losstype in param_dict[task_name][1]:
        fig.add_trace(go.Scatter(
            x=df[f'edges_{losstype}'], y=df[f'normalized_faithfulness_{losstype}'], mode='lines',
            name=losstype, line=dict(color=trace_colors[losstype]), legendgroup=losstype, showlegend=show_legend
        ), row=row, col=col)

    # Allow each subplot to have independent y-axis
    fig.update_yaxes(matches=None, row=row, col=col)

# Global layout settings
fig.update_layout(
    height=400, width=1000, title_text="",
    showlegend=True,
    legend=dict(
        orientation="h",  # Horizontal legend
        yanchor="bottom",  # Anchor to the bottom
        y=-0.4,  # Position below the plot
        xanchor="center",
        x=0.5
    )
)
fig.update_yaxes(range=[-0.1, 1.0], row=1, col=1)
fig.update_yaxes(range=[-0.1, 1.0], row=1, col=2)
fig.update_yaxes(nticks=8, row=1, col=1)
fig.update_xaxes(nticks=8, row=1, col=1)
fig.update_xaxes(nticks=8, row=1, col=2)

fig.update_layout(
    plot_bgcolor='white',  # White background
    paper_bgcolor='white'  # White figure background
)

# Ensure grid and zero lines are light gray
fig.update_xaxes(showgrid=True, gridcolor='lightgray', zeroline=True, zerolinecolor='lightgray')
fig.update_yaxes(showgrid=True, gridcolor='lightgray', zeroline=True, zerolinecolor='lightgray')

# X and Y labels (custom positioning)
fig.update_xaxes(title_text=f'Edges included (/{total_edges})')
fig.update_yaxes(title_text='Normalized faithfulness', row=1, col=1)

# Show figure
fig.show()

# %%
fig.write_image(f"./output/normalized_faithfulness.svg")

# %% [markdown]
# ### Bias heatmaps

# %%
import torch

# Specify the path to the .pth file
pth_file_path = 'vul_heads_og_method_bias.pth'

# Load the tensor from the .pth file
act_patching_tensor = torch.load(pth_file_path, map_location=torch.device('cpu'))
act_patching_tensor.requires_grad = False
# Print the loaded tensor
act_patching_tensor.shape
# Out:
# /var/folders/ts/2_ky83950p3_q8mq0075gb1c0000gn/T/ipykernel_12090/2083390844.py:7: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# torch.Size([16, 32])

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.graph import Graph


graph_path = "./full_adv_bias_EAP-IG_step3000_2357edges.json"

g = Graph.from_json(graph_path)

# %%
import pandas as pd

heatmap_dict = dict()

for node_str in g.nodes:
    node = g.nodes[node_str]
    if node.in_graph and "a" in node_str:
        print(node)
        heatmap_dict[node_str] = 0
        for p_edge in node.parent_edges:
            if p_edge.in_graph:
                heatmap_dict[node_str] += p_edge.score
                print(p_edge)
                print(p_edge.parent)
                print(p_edge.child)
        for c_edge in node.child_edges:
            if c_edge.in_graph:
                pass
                # print(c_edge)
                # print(c_edge.parent)
                # print(c_edge.child)

heatmap_dict
# Out:
# Node(a0.h2, in_graph: True)
# Edge(input->a0.h2<q>, score: 0.0006232046871446073, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h2, in_graph: True)
# Edge(input->a0.h2<k>, score: 0.0015502066817134619, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a0.h3, in_graph: True)
# Edge(input->a0.h3<q>, score: 0.0010811270913109183, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h3, in_graph: True)
# Node(a0.h6, in_graph: True)
# Edge(input->a0.h6<k>, score: 0.0011417785426601768, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h6, in_graph: True)
# Node(a0.h24, in_graph: True)
# Edge(input->a0.h24<q>, score: 0.0004902833607047796, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a0.h25, in_graph: True)
# Edge(input->a0.h25<q>, score: -0.0006833298248238862, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h25, in_graph: True)
# Node(a0.h29, in_graph: True)
# Edge(input->a0.h29<q>, score: 0.0015183762880042195, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h29, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(m0->a1.h3<v>, score: 0.0007961218361742795, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a1.h9, in_graph: True)
# Edge(m0->a1.h9<q>, score: 0.0008253492414951324, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h9, in_graph: True)
# Node(a1.h12, in_graph: True)
# Edge(m0->a1.h12<q>, score: -0.0004866595845669508, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h12, in_graph: True)
# Node(a1.h20, in_graph: True)
# Edge(input->a1.h20<q>, score: 0.0005385961849242449, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h20, in_graph: True)
# Edge(m0->a1.h20<q>, score: 0.0005740227061323822, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a1.h26, in_graph: True)
# Edge(m0->a1.h26<q>, score: -0.0007599727832712233, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h26, in_graph: True)
# Node(a1.h28, in_graph: True)
# Edge(m0->a1.h28<q>, score: 0.000645423773676157, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m0->a2.h4<v>, score: 0.0008312072022818029, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m0->a2.h4<k>, score: -0.0004750009102281183, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m1->a2.h4<v>, score: 0.0007522878586314619, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h4, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m0->a2.h5<v>, score: 0.0005551895592361689, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h5, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h20->a2.h6<v>, score: 0.0009195275488309562, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(input->a2.h6<k>, score: 0.0011965598678216338, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m1->a2.h6<q>, score: -0.0006167548708617687, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(input->a2.h6<v>, score: 0.0004704511375166476, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m1->a2.h6<k>, score: 0.0009728623554110527, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m0->a2.h6<k>, score: -0.0006489217048510909, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Node(a2.h14, in_graph: True)
# Edge(m1->a2.h14<q>, score: 0.0007389038219116628, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h14, in_graph: True)
# Node(a2.h15, in_graph: True)
# Edge(m0->a2.h15<q>, score: 0.0005782812950201333, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h15, in_graph: True)
# Node(a2.h22, in_graph: True)
# Edge(m1->a2.h22<q>, score: 0.00047686375910416245, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h22, in_graph: True)
# Node(a2.h25, in_graph: True)
# Edge(m1->a2.h25<q>, score: -0.0005167612689547241, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h25, in_graph: True)
# Node(a2.h27, in_graph: True)
# Edge(m1->a2.h27<q>, score: -0.0005597788258455694, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h27, in_graph: True)
# Node(a3.h0, in_graph: True)
# Edge(m1->a3.h0<k>, score: -0.0007810237002559006, in_graph: True)
# Node(m1, in_graph: True)
# Node(a3.h0, in_graph: True)
# Edge(m2->a3.h0<q>, score: 0.0007066744728945196, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h0, in_graph: True)
# Edge(input->a3.h0<v>, score: 0.0005660539609380066, in_graph: True)
# Node(input, in_graph: True)
# Node(a3.h0, in_graph: True)
# Edge(m2->a3.h0<k>, score: -0.0013773262035101652, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h0, in_graph: True)
# Edge(m2->a3.h0<v>, score: -0.0004625713045243174, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h0, in_graph: True)
# Node(a3.h1, in_graph: True)
# Edge(m2->a3.h1<v>, score: 0.000599867373239249, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h1, in_graph: True)
# Edge(m1->a3.h1<v>, score: -0.00047587562585249543, in_graph: True)
# Node(m1, in_graph: True)
# Node(a3.h1, in_graph: True)
# Node(a3.h4, in_graph: True)
# Edge(m0->a3.h4<v>, score: -0.0005408424767665565, in_graph: True)
# Node(m0, in_graph: True)
# Node(a3.h4, in_graph: True)
# Edge(m2->a3.h4<k>, score: 0.0005067649181000888, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h4, in_graph: True)
# Edge(m2->a3.h4<v>, score: 0.00046624435344710946, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h4, in_graph: True)
# Edge(a2.h27->a3.h4<v>, score: 0.0006551576661877334, in_graph: True)
# Node(a2.h27, in_graph: True)
# Node(a3.h4, in_graph: True)
# Node(a3.h7, in_graph: True)
# Edge(m1->a3.h7<v>, score: 0.0007408453966490924, in_graph: True)
# Node(m1, in_graph: True)
# Node(a3.h7, in_graph: True)
# Edge(a2.h5->a3.h7<v>, score: -0.0006560519686900079, in_graph: True)
# Node(a2.h5, in_graph: True)
# Node(a3.h7, in_graph: True)
# Edge(a2.h6->a3.h7<v>, score: 0.0010127888526767492, in_graph: True)
# Node(a2.h6, in_graph: True)
# Node(a3.h7, in_graph: True)
# Node(a3.h9, in_graph: True)
# Edge(m2->a3.h9<q>, score: 0.0005862407269887626, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h9, in_graph: True)
# Node(a3.h22, in_graph: True)
# Edge(m2->a3.h22<q>, score: -0.0005706677911803126, in_graph: True)
# Node(m2, in_graph: True)
# Node(a3.h22, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m2->a4.h0<k>, score: -0.0012791183544322848, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m3->a4.h0<q>, score: -0.0011338901240378618, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m3->a4.h0<v>, score: -0.0017046312568709254, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m0->a4.h0<v>, score: -0.0008243804913945496, in_graph: True)
# Node(m0, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m1->a4.h0<k>, score: 0.0005698243039660156, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m2->a4.h0<q>, score: -0.00046348277828656137, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h0, in_graph: True)
# Edge(m2->a4.h0<v>, score: 0.0025523712392896414, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h0, in_graph: True)
# Node(a4.h1, in_graph: True)
# Edge(m3->a4.h1<q>, score: -0.0006837844266556203, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h1, in_graph: True)
# Node(a4.h2, in_graph: True)
# Edge(m2->a4.h2<v>, score: -0.000882614403963089, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h2, in_graph: True)
# Edge(a3.h22->a4.h2<v>, score: 0.00059424591017887, in_graph: True)
# Node(a3.h22, in_graph: True)
# Node(a4.h2, in_graph: True)
# Edge(m3->a4.h2<k>, score: -0.0005069522885605693, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h2, in_graph: True)
# Edge(m1->a4.h2<v>, score: 0.0007971415179781616, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h2, in_graph: True)
# Edge(m3->a4.h2<v>, score: -0.0014283857308328152, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a4.h3, in_graph: True)
# Edge(m0->a4.h3<v>, score: -0.0004934075404889882, in_graph: True)
# Node(m0, in_graph: True)
# Node(a4.h3, in_graph: True)
# Edge(m1->a4.h3<v>, score: 0.0007141889655031264, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h3, in_graph: True)
# Edge(m2->a4.h3<v>, score: 0.001088863704353571, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a4.h4, in_graph: True)
# Edge(m2->a4.h4<v>, score: 0.0004995580529794097, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h4, in_graph: True)
# Edge(m0->a4.h4<k>, score: 0.0007138156215660274, in_graph: True)
# Node(m0, in_graph: True)
# Node(a4.h4, in_graph: True)
# Node(a4.h5, in_graph: True)
# Edge(m2->a4.h5<v>, score: 0.0009578905301168561, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h5, in_graph: True)
# Edge(m3->a4.h5<v>, score: -0.000518455111887306, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h5, in_graph: True)
# Edge(m1->a4.h5<v>, score: -0.00047421586350537837, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h5, in_graph: True)
# Node(a4.h6, in_graph: True)
# Edge(m1->a4.h6<v>, score: -0.0008221475291065872, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h6, in_graph: True)
# Edge(m3->a4.h6<v>, score: 0.0014183147577568889, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h6, in_graph: True)
# Node(a4.h7, in_graph: True)
# Edge(m3->a4.h7<k>, score: -0.0005032735643908381, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h7, in_graph: True)
# Edge(m3->a4.h7<v>, score: 0.001114466111175716, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h7, in_graph: True)
# Node(a4.h10, in_graph: True)
# Edge(m3->a4.h10<q>, score: 0.0005621376330964267, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a4.h16, in_graph: True)
# Edge(m3->a4.h16<q>, score: -0.0005776909529231489, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h16, in_graph: True)
# Node(a4.h19, in_graph: True)
# Edge(m0->a4.h19<q>, score: 0.0006865473696961999, in_graph: True)
# Node(m0, in_graph: True)
# Node(a4.h19, in_graph: True)
# Edge(m2->a4.h19<q>, score: 0.0005662368494085968, in_graph: True)
# Node(m2, in_graph: True)
# Node(a4.h19, in_graph: True)
# Node(a4.h23, in_graph: True)
# Edge(m3->a4.h23<q>, score: 0.0004902128712274134, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h23, in_graph: True)
# Node(a4.h26, in_graph: True)
# Edge(m3->a4.h26<q>, score: -0.0004648536560125649, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h26, in_graph: True)
# Node(a4.h28, in_graph: True)
# Edge(m3->a4.h28<q>, score: 0.0010557611240074039, in_graph: True)
# Node(m3, in_graph: True)
# Node(a4.h28, in_graph: True)
# Node(a4.h29, in_graph: True)
# Edge(m1->a4.h29<q>, score: 0.0007371396641246974, in_graph: True)
# Node(m1, in_graph: True)
# Node(a4.h29, in_graph: True)
# Edge(m0->a4.h29<q>, score: 0.0006118047167547047, in_graph: True)
# Node(m0, in_graph: True)
# Node(a4.h29, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(m3->a5.h0<v>, score: 0.0007110299193300307, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(a4.h2->a5.h0<q>, score: -0.0004996340721845627, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(m2->a5.h0<q>, score: 0.0009423140436410904, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(a4.h10->a5.h0<q>, score: 0.0006035800324752927, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(a3.h9->a5.h0<q>, score: 0.0005147477495484054, in_graph: True)
# Node(a3.h9, in_graph: True)
# Node(a5.h0, in_graph: True)
# Edge(m0->a5.h0<q>, score: 0.0009416785323992372, in_graph: True)
# Node(m0, in_graph: True)
# Node(a5.h0, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(a4.h10->a5.h1<q>, score: -0.0006722246762365103, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(a4.h3->a5.h1<k>, score: 0.0006555162253789604, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(a4.h2->a5.h1<q>, score: 0.0006757419905625284, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(m3->a5.h1<q>, score: -0.0006412760121747851, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(m4->a5.h1<q>, score: -0.0014213606482371688, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(m4->a5.h1<k>, score: -0.0010964247630909085, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(m2->a5.h1<q>, score: -0.0007922304794192314, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h1, in_graph: True)
# Edge(m4->a5.h1<v>, score: -0.0005326244281604886, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h1, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m4->a5.h3<k>, score: 0.0012213197769597173, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m3->a5.h3<q>, score: 0.0005915972287766635, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m1->a5.h3<v>, score: -0.0005148330237716436, in_graph: True)
# Node(m1, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m0->a5.h3<k>, score: 0.0013391132233664393, in_graph: True)
# Node(m0, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m1->a5.h3<k>, score: 0.0005244288477115333, in_graph: True)
# Node(m1, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m4->a5.h3<v>, score: 0.0006996353040449321, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m3->a5.h3<v>, score: 0.0005037908558733761, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m4->a5.h3<q>, score: 0.0013614353956654668, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h3, in_graph: True)
# Edge(m2->a5.h3<k>, score: 0.0011963032884523273, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h3, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(a4.h10->a5.h4<v>, score: -0.0005010724416933954, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(m4->a5.h4<q>, score: 0.0009391579660587013, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(a4.h2->a5.h4<v>, score: -0.0005312675493769348, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(a4.h5->a5.h4<q>, score: -0.0006549360696226358, in_graph: True)
# Node(a4.h5, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(m3->a5.h4<q>, score: -0.0005626074853353202, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h4, in_graph: True)
# Edge(a3.h9->a5.h4<q>, score: -0.0004832884296774864, in_graph: True)
# Node(a3.h9, in_graph: True)
# Node(a5.h4, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(a4.h3->a5.h5<k>, score: -0.0006196838221512735, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(m4->a5.h5<v>, score: 0.000684029480908066, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(m4->a5.h5<q>, score: -0.0013774147955700755, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(m3->a5.h5<k>, score: -0.0006708827568218112, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(m2->a5.h5<v>, score: -0.001135802362114191, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(m2->a5.h5<q>, score: -0.0005023800185881555, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h5, in_graph: True)
# Edge(a4.h10->a5.h5<q>, score: -0.0005635360139422119, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a5.h5, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(m4->a5.h6<q>, score: -0.0010441044578328729, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(m3->a5.h6<q>, score: 0.0006581618799827993, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(m1->a5.h6<q>, score: 0.0005393727333284914, in_graph: True)
# Node(m1, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(a4.h1->a5.h6<v>, score: 0.0009362166165374219, in_graph: True)
# Node(a4.h1, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(m3->a5.h6<v>, score: -0.001339848036877811, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(a4.h28->a5.h6<v>, score: 0.0007675471133552492, in_graph: True)
# Node(a4.h28, in_graph: True)
# Node(a5.h6, in_graph: True)
# Edge(m4->a5.h6<v>, score: 0.003072560764849186, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h6, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(a4.h10->a5.h7<q>, score: 0.0007974960026331246, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(m3->a5.h7<v>, score: -0.0008868619916029274, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(a4.h2->a5.h7<v>, score: -0.000530666031409055, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(m4->a5.h7<q>, score: 0.0028351026121526957, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(m3->a5.h7<q>, score: 0.0008729099645279348, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h7, in_graph: True)
# Edge(m4->a5.h7<v>, score: 0.000936449971050024, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a5.h8, in_graph: True)
# Edge(m0->a5.h8<q>, score: 0.0005312194698490202, in_graph: True)
# Node(m0, in_graph: True)
# Node(a5.h8, in_graph: True)
# Edge(m4->a5.h8<q>, score: -0.0010170856257900596, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h8, in_graph: True)
# Node(a5.h9, in_graph: True)
# Edge(m4->a5.h9<q>, score: -0.0009851910872384906, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h9, in_graph: True)
# Node(a5.h10, in_graph: True)
# Edge(m4->a5.h10<q>, score: 0.001077826484106481, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h10, in_graph: True)
# Node(a5.h12, in_graph: True)
# Edge(m4->a5.h12<q>, score: 0.0009646796970628202, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h12, in_graph: True)
# Edge(m3->a5.h12<q>, score: 0.0008353397133760154, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h12, in_graph: True)
# Node(a5.h14, in_graph: True)
# Edge(m4->a5.h14<q>, score: -0.00048626266652718186, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h14, in_graph: True)
# Node(a5.h15, in_graph: True)
# Edge(m3->a5.h15<q>, score: -0.000483949261251837, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h15, in_graph: True)
# Edge(m4->a5.h15<q>, score: -0.0006903378525748849, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h15, in_graph: True)
# Node(a5.h20, in_graph: True)
# Edge(m3->a5.h20<q>, score: 0.0005749788833782077, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h20, in_graph: True)
# Node(a5.h21, in_graph: True)
# Edge(m4->a5.h21<q>, score: -0.00046962304622866213, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h21, in_graph: True)
# Node(a5.h22, in_graph: True)
# Edge(m4->a5.h22<q>, score: -0.0027065426111221313, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h22, in_graph: True)
# Node(a5.h23, in_graph: True)
# Edge(m2->a5.h23<q>, score: 0.0005950701306574047, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h23, in_graph: True)
# Node(a5.h25, in_graph: True)
# Edge(m4->a5.h25<q>, score: -0.0005816931370645761, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h25, in_graph: True)
# Edge(m3->a5.h25<q>, score: 0.0007769559160806239, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h25, in_graph: True)
# Node(a5.h28, in_graph: True)
# Edge(m3->a5.h28<q>, score: 0.0004762535390909761, in_graph: True)
# Node(m3, in_graph: True)
# Node(a5.h28, in_graph: True)
# Edge(m2->a5.h28<q>, score: 0.0006137221935205162, in_graph: True)
# Node(m2, in_graph: True)
# Node(a5.h28, in_graph: True)
# Edge(m4->a5.h28<q>, score: 0.0019113924354314804, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h28, in_graph: True)
# Node(a5.h31, in_graph: True)
# Edge(m4->a5.h31<q>, score: -0.0007397685549221933, in_graph: True)
# Node(m4, in_graph: True)
# Node(a5.h31, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m3->a6.h0<v>, score: -0.0006552341510541737, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(a5.h15->a6.h0<v>, score: -0.0005288459360599518, in_graph: True)
# Node(a5.h15, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m2->a6.h0<v>, score: 0.0008889402379281819, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(a4.h2->a6.h0<v>, score: 0.0006212282460182905, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m5->a6.h0<v>, score: 0.0014947770396247506, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m4->a6.h0<q>, score: -0.001232096808962524, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m5->a6.h0<q>, score: 0.0005995497922413051, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(a4.h3->a6.h0<v>, score: -0.0006256864871829748, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(a5.h25->a6.h0<v>, score: 0.00046676621423102915, in_graph: True)
# Node(a5.h25, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m4->a6.h0<k>, score: 0.0006402631988748908, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(m5->a6.h0<k>, score: -0.000956056930590421, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h0, in_graph: True)
# Edge(a5.h28->a6.h0<v>, score: 0.00046370571362785995, in_graph: True)
# Node(a5.h28, in_graph: True)
# Node(a6.h0, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m2->a6.h1<v>, score: 0.0010631990153342485, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m5->a6.h1<v>, score: 0.003896660404279828, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h25->a6.h1<v>, score: -0.0011853553587570786, in_graph: True)
# Node(a5.h25, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h7->a6.h1<v>, score: 0.002300855703651905, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h1->a6.h1<v>, score: 0.0004829898534808308, in_graph: True)
# Node(a5.h1, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a4.h10->a6.h1<v>, score: -0.0007568837027065456, in_graph: True)
# Node(a4.h10, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m5->a6.h1<k>, score: -0.001125854323618114, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a3.h22->a6.h1<v>, score: -0.0006832932122051716, in_graph: True)
# Node(a3.h22, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a4.h16->a6.h1<v>, score: -0.0013704551383852959, in_graph: True)
# Node(a4.h16, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m4->a6.h1<q>, score: 0.0007442704518325627, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a4.h19->a6.h1<v>, score: 0.0006009134813211858, in_graph: True)
# Node(a4.h19, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h5->a6.h1<v>, score: -0.0015939539298415184, in_graph: True)
# Node(a5.h5, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a4.h2->a6.h1<v>, score: 0.0005956005188636482, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h9->a6.h1<v>, score: -0.0005312831490300596, in_graph: True)
# Node(a5.h9, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a4.h3->a6.h1<v>, score: 0.0021179208997637033, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m4->a6.h1<k>, score: 0.0007326792110688984, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m3->a6.h1<v>, score: 0.001035452471114695, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(a5.h6->a6.h1<v>, score: 0.0010158865479752421, in_graph: True)
# Node(a5.h6, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m4->a6.h1<v>, score: -0.005003419704735279, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h1, in_graph: True)
# Edge(m3->a6.h1<k>, score: -0.0007091021980158985, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h1, in_graph: True)
# Node(a6.h2, in_graph: True)
# Edge(m5->a6.h2<q>, score: -0.00047238115803338587, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h2, in_graph: True)
# Edge(m4->a6.h2<q>, score: 0.0006809420883655548, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h2, in_graph: True)
# Edge(m4->a6.h2<v>, score: 0.0009587575914338231, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h2, in_graph: True)
# Node(a6.h3, in_graph: True)
# Edge(m5->a6.h3<v>, score: 0.0005950158811174333, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h3, in_graph: True)
# Node(a6.h4, in_graph: True)
# Edge(m4->a6.h4<q>, score: 0.0008849724545143545, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h4, in_graph: True)
# Edge(m5->a6.h4<k>, score: 0.0009160418412648141, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h4, in_graph: True)
# Edge(m4->a6.h4<v>, score: -0.0007979191141203046, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h4, in_graph: True)
# Edge(m5->a6.h4<v>, score: -0.0014846445992588997, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h4, in_graph: True)
# Edge(a4.h2->a6.h4<v>, score: 0.0007889905828051269, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a6.h4, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(a4.h3->a6.h5<v>, score: 0.0008892557816579938, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(input->a6.h5<v>, score: -0.0004946684348396957, in_graph: True)
# Node(input, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(a4.h29->a6.h5<v>, score: 0.0005571530782617629, in_graph: True)
# Node(a4.h29, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(m5->a6.h5<v>, score: -0.0006183048244565725, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(m4->a6.h5<v>, score: 0.0010632002959027886, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(m3->a6.h5<q>, score: 0.0005425763665698469, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(m5->a6.h5<k>, score: 0.0012918327702209353, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(a5.h12->a6.h5<v>, score: 0.0006596457096748054, in_graph: True)
# Node(a5.h12, in_graph: True)
# Node(a6.h5, in_graph: True)
# Edge(a5.h28->a6.h5<v>, score: 0.0006425983738154173, in_graph: True)
# Node(a5.h28, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(m3->a6.h6<q>, score: 0.000647872278932482, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(m5->a6.h6<q>, score: 0.0015381721314042807, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(m2->a6.h6<v>, score: 0.0018628316465765238, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(a4.h3->a6.h6<v>, score: -0.0008769495761953294, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(m4->a6.h6<v>, score: 0.0008360240608453751, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h6, in_graph: True)
# Edge(m3->a6.h6<v>, score: -0.0006614807061851025, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m0->a6.h7<v>, score: 0.0005405336269177496, in_graph: True)
# Node(m0, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m5->a6.h7<k>, score: -0.0005346025573089719, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m3->a6.h7<k>, score: -0.0006181995267979801, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m4->a6.h7<v>, score: -0.0012592710554599762, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m3->a6.h7<v>, score: -0.00084282411262393, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h7, in_graph: True)
# Edge(m1->a6.h7<v>, score: 0.0006740775424987078, in_graph: True)
# Node(m1, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a6.h8, in_graph: True)
# Edge(m3->a6.h8<q>, score: -0.001173375523649156, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h8, in_graph: True)
# Edge(m5->a6.h8<q>, score: -0.0008911257609724998, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h8, in_graph: True)
# Edge(m4->a6.h8<q>, score: 0.0008809749269858003, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h8, in_graph: True)
# Node(a6.h9, in_graph: True)
# Edge(m5->a6.h9<q>, score: 0.0005371926818042994, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h9, in_graph: True)
# Edge(m3->a6.h9<q>, score: 0.0012771815527230501, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h9, in_graph: True)
# Edge(m4->a6.h9<q>, score: -0.0017561715794727206, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h9, in_graph: True)
# Node(a6.h10, in_graph: True)
# Edge(m4->a6.h10<q>, score: 0.0007750990916974843, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h10, in_graph: True)
# Node(a6.h11, in_graph: True)
# Edge(m2->a6.h11<q>, score: 0.0012337053194642067, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h11, in_graph: True)
# Edge(m3->a6.h11<q>, score: -0.0007261722348630428, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h11, in_graph: True)
# Edge(m4->a6.h11<q>, score: 0.002426501829177141, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h11, in_graph: True)
# Node(a6.h13, in_graph: True)
# Edge(m5->a6.h13<q>, score: 0.00048382283421233296, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h13, in_graph: True)
# Node(a6.h14, in_graph: True)
# Edge(m5->a6.h14<q>, score: -0.0005841002566739917, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h14, in_graph: True)
# Edge(m4->a6.h14<q>, score: 0.0005572514492087066, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h14, in_graph: True)
# Node(a6.h16, in_graph: True)
# Edge(m4->a6.h16<q>, score: 0.0017477984074503183, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h16, in_graph: True)
# Edge(m3->a6.h16<q>, score: 0.0004684752784669399, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h16, in_graph: True)
# Edge(m5->a6.h16<q>, score: -0.0008181549492292106, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h16, in_graph: True)
# Node(a6.h17, in_graph: True)
# Edge(m4->a6.h17<q>, score: -0.0009849853813648224, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h17, in_graph: True)
# Edge(m5->a6.h17<q>, score: 0.0010012804996222258, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h17, in_graph: True)
# Node(a6.h18, in_graph: True)
# Edge(m5->a6.h18<q>, score: 0.0004752783279400319, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h18, in_graph: True)
# Edge(m4->a6.h18<q>, score: -0.0007472981815226376, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h18, in_graph: True)
# Node(a6.h19, in_graph: True)
# Edge(m5->a6.h19<q>, score: 0.0005945306038483977, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h19, in_graph: True)
# Edge(m3->a6.h19<q>, score: 0.0005242537008598447, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h19, in_graph: True)
# Edge(m4->a6.h19<q>, score: -0.0010838318848982453, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h19, in_graph: True)
# Node(a6.h22, in_graph: True)
# Edge(m4->a6.h22<q>, score: 0.000522633723448962, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h22, in_graph: True)
# Edge(m5->a6.h22<q>, score: 0.0007766265771351755, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a6.h23, in_graph: True)
# Edge(m5->a6.h23<q>, score: -0.0005488793249242008, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h23, in_graph: True)
# Node(a6.h25, in_graph: True)
# Edge(m5->a6.h25<q>, score: 0.0007485473179258406, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h25, in_graph: True)
# Node(a6.h28, in_graph: True)
# Edge(m3->a6.h28<q>, score: -0.0005756939644925296, in_graph: True)
# Node(m3, in_graph: True)
# Node(a6.h28, in_graph: True)
# Edge(m2->a6.h28<q>, score: 0.0006700623198412359, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h28, in_graph: True)
# Node(a6.h29, in_graph: True)
# Edge(m5->a6.h29<q>, score: 0.0005158885614946485, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h29, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(a5.h25->a6.h30<q>, score: -0.0006728296284563839, in_graph: True)
# Node(a5.h25, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(m2->a6.h30<q>, score: -0.0013758811401203275, in_graph: True)
# Node(m2, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(a5.h7->a6.h30<q>, score: -0.0005368142738007009, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(m4->a6.h30<q>, score: 0.0010260328417643905, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(a4.h3->a6.h30<q>, score: 0.0007332728710025549, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(a4.h1->a6.h30<q>, score: -0.0006683856481686234, in_graph: True)
# Node(a4.h1, in_graph: True)
# Node(a6.h30, in_graph: True)
# Edge(m0->a6.h30<q>, score: -0.0006097810110077262, in_graph: True)
# Node(m0, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a6.h31, in_graph: True)
# Edge(m5->a6.h31<q>, score: -0.0008311470155604184, in_graph: True)
# Node(m5, in_graph: True)
# Node(a6.h31, in_graph: True)
# Edge(m4->a6.h31<q>, score: 0.0010166261345148087, in_graph: True)
# Node(m4, in_graph: True)
# Node(a6.h31, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h5->a7.h0<k>, score: 0.0008753508445806801, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h9->a7.h0<v>, score: -0.0007585198036395013, in_graph: True)
# Node(a6.h9, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h8->a7.h0<v>, score: 0.0013295152457430959, in_graph: True)
# Node(a6.h8, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a4.h2->a7.h0<v>, score: -0.0008695274009369314, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(m6->a7.h0<v>, score: -0.003176965517923236, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(m3->a7.h0<v>, score: 0.0005437691579572856, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(m6->a7.h0<k>, score: 0.0011756616877391934, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(m5->a7.h0<k>, score: -0.0004863787617068738, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h11->a7.h0<v>, score: -0.0010465302038937807, in_graph: True)
# Node(a6.h11, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h30->a7.h0<v>, score: -0.0007013670983724296, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(m2->a7.h0<v>, score: 0.0006024141912348568, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h22->a7.h0<v>, score: -0.0008821032824926078, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h5->a7.h0<v>, score: -0.0004638410173356533, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h6->a7.h0<v>, score: 0.0006393923540599644, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h0, in_graph: True)
# Edge(a6.h7->a7.h0<v>, score: 0.0006181689677760005, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a7.h0, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a4.h3->a7.h1<v>, score: -0.002150855725631118, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h16->a7.h1<v>, score: -0.0009266701526939869, in_graph: True)
# Node(a6.h16, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h3->a7.h1<v>, score: -0.0011213761754333973, in_graph: True)
# Node(a6.h3, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h31->a7.h1<v>, score: 0.0006567695527337492, in_graph: True)
# Node(a6.h31, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h2->a7.h1<v>, score: -0.0007397850858978927, in_graph: True)
# Node(a6.h2, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a5.h7->a7.h1<v>, score: 0.0006743067060597241, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h7->a7.h1<v>, score: -0.000638697121758014, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m3->a7.h1<v>, score: 0.0023365062661468983, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h22->a7.h1<v>, score: -0.0009536890429444611, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m2->a7.h1<k>, score: -0.0005480355466715991, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h14->a7.h1<v>, score: -0.0007260371348820627, in_graph: True)
# Node(a6.h14, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h0->a7.h1<v>, score: 0.0008538388065062463, in_graph: True)
# Node(a6.h0, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m5->a7.h1<k>, score: 0.0018143216148018837, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a5.h12->a7.h1<v>, score: -0.0005348497070372105, in_graph: True)
# Node(a5.h12, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m6->a7.h1<v>, score: 0.005012630484998226, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h5->a7.h1<v>, score: -0.003025397192686796, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h30->a7.h1<v>, score: -0.0007306970655918121, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m5->a7.h1<v>, score: 0.004033309873193502, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h3->a7.h1<k>, score: 0.0004735479305963963, in_graph: True)
# Node(a6.h3, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a6.h6->a7.h1<v>, score: 0.0024520454462617636, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(m4->a7.h1<v>, score: 0.0019400721648707986, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h1, in_graph: True)
# Edge(a4.h2->a7.h1<v>, score: 0.0004982527461834252, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a7.h1, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a4.h1->a7.h2<v>, score: -0.0009246682748198509, in_graph: True)
# Node(a4.h1, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h31->a7.h2<v>, score: -0.0005567421321757138, in_graph: True)
# Node(a6.h31, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m6->a7.h2<v>, score: 0.001558776362799108, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a5.h14->a7.h2<v>, score: 0.0006209547282196581, in_graph: True)
# Node(a5.h14, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a4.h3->a7.h2<v>, score: 0.0016225960571318865, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m5->a7.h2<v>, score: -0.0030553971882909536, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h4->a7.h2<v>, score: -0.001449328730814159, in_graph: True)
# Node(a6.h4, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(input->a7.h2<v>, score: 0.0011783527443185449, in_graph: True)
# Node(input, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m1->a7.h2<v>, score: 0.0007117810309864581, in_graph: True)
# Node(m1, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h1->a7.h2<v>, score: 0.0008865193813107908, in_graph: True)
# Node(a6.h1, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m2->a7.h2<v>, score: 0.0033128231298178434, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h30->a7.h2<v>, score: -0.00047201552661135793, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h9->a7.h2<v>, score: -0.0005954838707111776, in_graph: True)
# Node(a6.h9, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h22->a7.h2<v>, score: 0.003218507394194603, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a4.h2->a7.h2<v>, score: -0.0017877385253086686, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m4->a7.h2<q>, score: 0.0007040930213406682, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m5->a7.h2<k>, score: 0.001110969576984644, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a5.h12->a7.h2<v>, score: 0.0011957980459555984, in_graph: True)
# Node(a5.h12, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m5->a7.h2<q>, score: -0.000595502438955009, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m4->a7.h2<k>, score: -0.0008784499950706959, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m3->a7.h2<k>, score: -0.0005765375681221485, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h29->a7.h2<v>, score: 0.0005584023892879486, in_graph: True)
# Node(a6.h29, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m0->a7.h2<v>, score: -0.0016788685461506248, in_graph: True)
# Node(m0, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a4.h0->a7.h2<v>, score: 0.0006282061222009361, in_graph: True)
# Node(a4.h0, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a5.h25->a7.h2<v>, score: 0.0007866189698688686, in_graph: True)
# Node(a5.h25, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m2->a7.h2<k>, score: 0.0004654445219784975, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h23->a7.h2<v>, score: 0.0005109068588353693, in_graph: True)
# Node(a6.h23, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h25->a7.h2<v>, score: -0.0005156624829396605, in_graph: True)
# Node(a6.h25, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h7->a7.h2<v>, score: -0.0028113105800002813, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h10->a7.h2<v>, score: -0.0005890482570976019, in_graph: True)
# Node(a6.h10, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h11->a7.h2<v>, score: 0.0008556636166758835, in_graph: True)
# Node(a6.h11, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m3->a7.h2<v>, score: -0.004583694972097874, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h6->a7.h2<v>, score: -0.0018713315948843956, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m4->a7.h2<v>, score: -0.0014967108145356178, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h17->a7.h2<v>, score: 0.0007181259570643306, in_graph: True)
# Node(a6.h17, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h16->a7.h2<v>, score: -0.0005909099127165973, in_graph: True)
# Node(a6.h16, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h5->a7.h2<v>, score: 0.015288871712982655, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h0->a7.h2<v>, score: 0.0006673297611996531, in_graph: True)
# Node(a6.h0, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(a6.h28->a7.h2<v>, score: 0.000591660791542381, in_graph: True)
# Node(a6.h28, in_graph: True)
# Node(a7.h2, in_graph: True)
# Edge(m6->a7.h2<k>, score: 0.0013038149336352944, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h2, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(a6.h7->a7.h3<v>, score: 0.0007962838863022625, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(a6.h5->a7.h3<v>, score: -0.0013973739696666598, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(m5->a7.h3<k>, score: -0.00047685648314654827, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(m6->a7.h3<v>, score: 0.0012192865833640099, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(a6.h16->a7.h3<v>, score: -0.0004930397844873369, in_graph: True)
# Node(a6.h16, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(a6.h6->a7.h3<v>, score: 0.0006844555027782917, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h3, in_graph: True)
# Edge(a6.h30->a7.h3<v>, score: -0.0005293702124617994, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h3, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(m4->a7.h4<k>, score: -0.0005424092523753643, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(m6->a7.h4<k>, score: -0.0005484715802595019, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(a6.h19->a7.h4<v>, score: -0.0005248801899142563, in_graph: True)
# Node(a6.h19, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(a6.h6->a7.h4<k>, score: -0.0007356004207395017, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(m4->a7.h4<v>, score: 0.0010813974076882005, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(a6.h5->a7.h4<v>, score: 0.0005202433676458895, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(a6.h6->a7.h4<v>, score: -0.0005448416341096163, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(m2->a7.h4<v>, score: 0.0008194014662876725, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(m5->a7.h4<k>, score: -0.000990376458503306, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h4, in_graph: True)
# Edge(a6.h22->a7.h4<v>, score: -0.0008175121038220823, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a7.h4, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h14->a7.h5<v>, score: -0.0012199832126498222, in_graph: True)
# Node(a6.h14, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a5.h7->a7.h5<v>, score: 0.0019909185357391834, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m2->a7.h5<k>, score: -0.0006407962064258754, in_graph: True)
# Node(m2, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a4.h26->a7.h5<v>, score: -0.0005065440782345831, in_graph: True)
# Node(a4.h26, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m1->a7.h5<v>, score: 0.001540066208690405, in_graph: True)
# Node(m1, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(input->a7.h5<v>, score: -0.0005020477692596614, in_graph: True)
# Node(input, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h29->a7.h5<v>, score: -0.001036820001900196, in_graph: True)
# Node(a6.h29, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h23->a7.h5<k>, score: -0.0012112387921661139, in_graph: True)
# Node(a6.h23, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h7->a7.h5<q>, score: -0.00047200126573443413, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h5->a7.h5<v>, score: -0.0015293386531993747, in_graph: True)
# Node(a6.h5, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m3->a7.h5<v>, score: -0.0030375064816325903, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a4.h2->a7.h5<v>, score: -0.0008768595871515572, in_graph: True)
# Node(a4.h2, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a5.h5->a7.h5<v>, score: -0.000755518616642803, in_graph: True)
# Node(a5.h5, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h30->a7.h5<v>, score: 0.0011214188998565078, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m5->a7.h5<k>, score: 0.0021444957237690687, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m6->a7.h5<v>, score: -0.0018610124243423343, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a4.h3->a7.h5<k>, score: 0.0010448331013321877, in_graph: True)
# Node(a4.h3, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h22->a7.h5<k>, score: 0.0020930382888764143, in_graph: True)
# Node(a6.h22, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h10->a7.h5<v>, score: 0.000617469719145447, in_graph: True)
# Node(a6.h10, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m0->a7.h5<v>, score: 0.0005727525567635894, in_graph: True)
# Node(m0, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m5->a7.h5<v>, score: 0.001799766207113862, in_graph: True)
# Node(m5, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h4->a7.h5<v>, score: 0.0007297806441783905, in_graph: True)
# Node(a6.h4, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h29->a7.h5<k>, score: 0.0007187296869233251, in_graph: True)
# Node(a6.h29, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h30->a7.h5<k>, score: -0.0005894947098568082, in_graph: True)
# Node(a6.h30, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a5.h7->a7.h5<k>, score: 0.0009920266456902027, in_graph: True)
# Node(a5.h7, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m0->a7.h5<k>, score: -0.0004871017299592495, in_graph: True)
# Node(m0, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m6->a7.h5<k>, score: 0.0009218993945978582, in_graph: True)
# Node(m6, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a5.h28->a7.h5<v>, score: -0.0006507049547508359, in_graph: True)
# Node(a5.h28, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m3->a7.h5<k>, score: 0.002599936444312334, in_graph: True)
# Node(m3, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h6->a7.h5<k>, score: 0.0005592338275164366, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(m4->a7.h5<k>, score: 0.0021080845035612583, in_graph: True)
# Node(m4, in_graph: True)
# Node(a7.h5, in_graph: True)
# Edge(a6.h16->a7.h5<v>, score: 0.000874353398103267, in_graph: True)
# Node(a6.h16, in_graph: True)
# ...
# Node(a10.h13, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a9.h24->a15.h3<v>, score: 0.0008744944934733212, in_graph: True)
# Node(a9.h24, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a13.h4->a15.h3<v>, score: 0.0010203731944784522, in_graph: True)
# Node(a13.h4, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a7.h10->a15.h3<v>, score: -0.000534285616595298, in_graph: True)
# Node(a7.h10, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(m7->a15.h3<v>, score: -0.001315337955020368, in_graph: True)
# Node(m7, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a7.h22->a15.h3<v>, score: -0.0005747460527345538, in_graph: True)
# Node(a7.h22, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a11.h11->a15.h3<v>, score: 0.0005482555134221911, in_graph: True)
# Node(a11.h11, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(m13->a15.h3<v>, score: 0.0014734930591657758, in_graph: True)
# Node(m13, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(m10->a15.h3<v>, score: -0.0017235446721315384, in_graph: True)
# Node(m10, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a8.h31->a15.h3<v>, score: 0.0006860705325379968, in_graph: True)
# Node(a8.h31, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(m8->a15.h3<v>, score: 0.0010454881703481078, in_graph: True)
# Node(m8, in_graph: True)
# Node(a15.h3, in_graph: True)
# Edge(a10.h14->a15.h3<v>, score: -0.0005349881830625236, in_graph: True)
# Node(a10.h14, in_graph: True)
# Node(a15.h3, in_graph: True)
# Node(a15.h5, in_graph: True)
# Edge(m9->a15.h5<v>, score: -0.0008988659246824682, in_graph: True)
# Node(m9, in_graph: True)
# Node(a15.h5, in_graph: True)
# Edge(m13->a15.h5<v>, score: -0.0005472010816447437, in_graph: True)
# Node(m13, in_graph: True)
# Node(a15.h5, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m14->a15.h6<v>, score: 0.0011272014817222953, in_graph: True)
# Node(m14, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m6->a15.h6<v>, score: 0.0005763269145973027, in_graph: True)
# Node(m6, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m10->a15.h6<v>, score: -0.0006890783552080393, in_graph: True)
# Node(m10, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m13->a15.h6<v>, score: -0.0009253195603378117, in_graph: True)
# Node(m13, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(a13.h4->a15.h6<v>, score: -0.00046720882528461516, in_graph: True)
# Node(a13.h4, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m9->a15.h6<v>, score: -0.0009927802020683885, in_graph: True)
# Node(m9, in_graph: True)
# Node(a15.h6, in_graph: True)
# Edge(m8->a15.h6<v>, score: -0.0006523753982037306, in_graph: True)
# Node(m8, in_graph: True)
# Node(a15.h6, in_graph: True)
# Node(a15.h12, in_graph: True)
# Edge(m10->a15.h12<q>, score: -0.0006733172340318561, in_graph: True)
# Node(m10, in_graph: True)
# Node(a15.h12, in_graph: True)
# Node(a15.h20, in_graph: True)
# Edge(m11->a15.h20<q>, score: -0.0006642613443545997, in_graph: True)
# Node(m11, in_graph: True)
# Node(a15.h20, in_graph: True)
# Node(a15.h28, in_graph: True)
# Edge(m10->a15.h28<q>, score: 0.0010714777745306492, in_graph: True)
# Node(m10, in_graph: True)
# Node(a15.h28, in_graph: True)
# Edge(a10.h14->a15.h28<q>, score: 0.0005757422186434269, in_graph: True)
# Node(a10.h14, in_graph: True)
# Node(a15.h28, in_graph: True)
# Edge(m7->a15.h28<q>, score: 0.0004793219268321991, in_graph: True)
# Node(m7, in_graph: True)
# Node(a15.h28, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a9.h24->a15.h29<q>, score: 0.002848423318937421, in_graph: True)
# Node(a9.h24, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a8.h7->a15.h29<q>, score: 0.0007043349905870855, in_graph: True)
# Node(a8.h7, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h24->a15.h29<q>, score: 0.0032870557624846697, in_graph: True)
# Node(a10.h24, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h25->a15.h29<q>, score: 0.0014371935976669192, in_graph: True)
# Node(a10.h25, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(m9->a15.h29<q>, score: 0.0011680647730827332, in_graph: True)
# Node(m9, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a8.h6->a15.h29<q>, score: -0.000493121740873903, in_graph: True)
# Node(a8.h6, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a11.h4->a15.h29<q>, score: -0.001133865094743669, in_graph: True)
# Node(a11.h4, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a12.h2->a15.h29<q>, score: -0.0027214824222028255, in_graph: True)
# Node(a12.h2, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h13->a15.h29<q>, score: 0.002113957656547427, in_graph: True)
# Node(a10.h13, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a13.h2->a15.h29<q>, score: -0.0006573108257725835, in_graph: True)
# Node(a13.h2, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h26->a15.h29<q>, score: 0.0040235561318695545, in_graph: True)
# Node(a10.h26, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a7.h20->a15.h29<q>, score: 0.0009634836460463703, in_graph: True)
# Node(a7.h20, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a9.h26->a15.h29<q>, score: -0.0005077988607808948, in_graph: True)
# Node(a9.h26, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h23->a15.h29<q>, score: 0.0028112626168876886, in_graph: True)
# Node(a10.h23, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a7.h22->a15.h29<q>, score: -0.0004816048312932253, in_graph: True)
# Node(a7.h22, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h14->a15.h29<q>, score: -0.006309762131422758, in_graph: True)
# Node(a10.h14, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a12.h15->a15.h29<q>, score: -0.0021996782161295414, in_graph: True)
# Node(a12.h15, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(m8->a15.h29<q>, score: 0.0005468978197313845, in_graph: True)
# Node(m8, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a6.h6->a15.h29<q>, score: 0.00047964227269403636, in_graph: True)
# Node(a6.h6, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(m10->a15.h29<q>, score: 0.001948624849319458, in_graph: True)
# Node(m10, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h12->a15.h29<q>, score: 0.0006713642505928874, in_graph: True)
# Node(a10.h12, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a6.h7->a15.h29<q>, score: 0.0005582524463534355, in_graph: True)
# Node(a6.h7, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a9.h25->a15.h29<q>, score: 0.0033129595685750246, in_graph: True)
# Node(a9.h25, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h22->a15.h29<q>, score: -0.002867684466764331, in_graph: True)
# Node(a10.h22, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a9.h27->a15.h29<q>, score: -0.001610043691471219, in_graph: True)
# Node(a9.h27, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a11.h8->a15.h29<q>, score: -0.0012013434898108244, in_graph: True)
# Node(a11.h8, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a7.h3->a15.h29<q>, score: -0.0006878084386698902, in_graph: True)
# Node(a7.h3, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a14.h22->a15.h29<q>, score: -0.0005971873179078102, in_graph: True)
# Node(a14.h22, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h20->a15.h29<q>, score: 0.002176205161958933, in_graph: True)
# Node(a10.h20, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(a10.h15->a15.h29<q>, score: -0.0038480868097394705, in_graph: True)
# Node(a10.h15, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(m11->a15.h29<q>, score: 0.001211268361657858, in_graph: True)
# Node(m11, in_graph: True)
# Node(a15.h29, in_graph: True)
# Edge(m14->a15.h29<q>, score: 0.0007372625404968858, in_graph: True)
# Node(m14, in_graph: True)
# Node(a15.h29, in_graph: True)
# Node(a15.h30, in_graph: True)
# Edge(a10.h14->a15.h30<q>, score: -0.0006902887835167348, in_graph: True)
# Node(a10.h14, in_graph: True)
# Node(a15.h30, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(m8->a15.h31<q>, score: -0.0005394166801124811, in_graph: True)
# Node(m8, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(a10.h15->a15.h31<q>, score: 0.0006362305721268058, in_graph: True)
# Node(a10.h15, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(a9.h24->a15.h31<q>, score: -0.0004704459279309958, in_graph: True)
# Node(a9.h24, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(a10.h14->a15.h31<q>, score: 0.0006587452371604741, in_graph: True)
# Node(a10.h14, in_graph: True)
# Node(a15.h31, in_graph: True)
# {'a0.h2': 0.002173411368858069,
#  'a0.h3': 0.0010811270913109183,
#  'a0.h6': 0.0011417785426601768,
#  'a0.h24': 0.0004902833607047796,
#  'a0.h25': -0.0006833298248238862,
#  'a0.h29': 0.0015183762880042195,
#  'a1.h3': 0.0007961218361742795,
#  'a1.h9': 0.0008253492414951324,
#  'a1.h12': -0.0004866595845669508,
#  'a1.h20': 0.001112618891056627,
#  'a1.h26': -0.0007599727832712233,
#  'a1.h28': 0.000645423773676157,
#  'a2.h4': 0.0011084941506851465,
#  'a2.h5': 0.0005551895592361689,
#  'a2.h6': 0.0022937243338674307,
#  'a2.h14': 0.0007389038219116628,
#  'a2.h15': 0.0005782812950201333,
#  'a2.h22': 0.00047686375910416245,
#  'a2.h25': -0.0005167612689547241,
#  'a2.h27': -0.0005597788258455694,
#  'a3.h0': -0.001348192774457857,
#  'a3.h1': 0.00012399174738675356,
#  'a3.h4': 0.0010873244609683752,
#  'a3.h7': 0.0010975822806358337,
#  'a3.h9': 0.0005862407269887626,
#  'a3.h22': -0.0005706677911803126,
#  'a4.h0': -0.002283307461766526,
#  'a4.h1': -0.0006837844266556203,
#  'a4.h2': -0.001426564995199442,
#  'a4.h3': 0.0013096451293677092,
#  'a4.h4': 0.001213373674545437,
#  'a4.h5': -3.478044527582824e-05,
#  'a4.h6': 0.0005961672286503017,
#  'a4.h7': 0.0006111925467848778,
#  'a4.h10': 0.0005621376330964267,
#  'a4.h16': -0.0005776909529231489,
#  'a4.h19': 0.0012527842191047966,
#  'a4.h23': 0.0004902128712274134,
#  'a4.h26': -0.0004648536560125649,
#  'a4.h28': 0.0010557611240074039,
#  'a4.h29': 0.0013489443808794022,
#  'a5.h0': 0.0032137162052094936,
#  'a5.h1': -0.003824882791377604,
#  'a5.h3': 0.006922790897078812,
#  'a5.h4': -0.0017940140096470714,
#  'a5.h5': -0.004185670288279653,
#  'a5.h6': 0.003589906613342464,
#  'a5.h7': 0.004024430527351797,
#  'a5.h8': -0.0004858661559410393,
#  'a5.h9': -0.0009851910872384906,
#  'a5.h10': 0.001077826484106481,
#  'a5.h12': 0.0018000194104388356,
#  'a5.h14': -0.00048626266652718186,
#  'a5.h15': -0.001174287113826722,
#  'a5.h20': 0.0005749788833782077,
#  'a5.h21': -0.00046962304622866213,
#  'a5.h22': -0.0027065426111221313,
#  'a5.h23': 0.0005950701306574047,
#  'a5.h25': 0.00019526277901604772,
#  'a5.h28': 0.0030013681680429727,
#  'a5.h31': -0.0007397685549221933,
#  'a6.h0': 0.0011773101286962628,
#  'a6.h1': 0.001626827841391787,
#  'a6.h2': 0.001167318521765992,
#  'a6.h3': 0.0005950158811174333,
#  'a6.h4': 0.00030744116520509124,
#  'a6.h5': 0.004533289116807282,
#  'a6.h6': 0.0033464698353782296,
#  'a6.h7': -0.0020402860827744007,
#  'a6.h8': -0.0011835263576358557,
#  'a6.h9': 5.820265505462885e-05,
#  'a6.h10': 0.0007750990916974843,
#  'a6.h11': 0.002934034913778305,
#  'a6.h13': 0.00048382283421233296,
#  'a6.h14': -2.6848807465285063e-05,
#  'a6.h16': 0.0013981187366880476,
#  'a6.h17': 1.6295118257403374e-05,
#  'a6.h18': -0.0002720198535826057,
#  'a6.h19': 3.495241980999708e-05,
#  'a6.h22': 0.0012992603005841374,
#  'a6.h23': -0.0005488793249242008,
#  'a6.h25': 0.0007485473179258406,
#  'a6.h28': 9.436835534870625e-05,
#  'a6.h29': 0.0005158885614946485,
#  'a6.h30': -0.0021043859887868166,
#  'a6.h31': 0.0001854791189543903,
#  'a7.h0': -0.002600960637209937,
#  'a7.h1': 0.008649511641124263,
#  'a7.h2': 0.013466815697029233,
#  'a7.h3': -0.00019661447731778026,
#  'a7.h4': -0.0022830493981018662,
#  'a7.h5': 0.00911963841645047,
#  'a7.h6': 0.001109458418795839,
#  'a7.h7': 0.00035004541859962046,
#  'a7.h9': -0.000554653990548104,
#  'a7.h10': 0.0009992128470912576,
#  'a7.h13': -0.0002591430093161762,
#  'a7.h14': -0.0005519769620150328,
#  'a7.h15': -0.0008770311542320997,
#  'a7.h16': -0.00022074789740145206,
#  'a7.h19': 0.0006418016273528337,
#  'a7.h20': -0.00135534827131778,
#  'a7.h21': 6.226147525012493e-05,
#  'a7.h22': -0.0004742280289065093,
#  'a7.h23': -0.0010445659281685948,
#  'a7.h24': 0.0005833290051668882,
#  'a7.h27': 0.00045452971244230866,
#  'a7.h28': 0.0006193880108185112,
#  'a7.h29': 0.00016447919188067317,
#  'a8.h0': 0.0010283447918482125,
#  'a8.h1': 0.009153043909464031,
#  'a8.h2': 0.006008692958857864,
#  'a8.h3': -0.0009645796380937099,
#  'a8.h4': -0.002342168358154595,
#  'a8.h5': -0.0024426752934232354,
#  'a8.h6': 0.005735851533245295,
#  'a8.h7': 0.005595021502813324,
#  'a8.h10': 0.0007476817700080574,
#  'a8.h11': 0.0004429245018400252,
#  'a8.h12': -0.004609698196873069,
#  'a8.h13': 0.0013317311531864107,
#  'a8.h14': 0.0004853786376770586,
#  'a8.h17': -0.0006940786261111498,
#  'a8.h20': -0.0007455726154148579,
#  'a8.h21': 0.0025181013625115156,
#  'a8.h24': -8.961584535427392e-05,
#  'a8.h26': -0.00046625008690170944,
#  'a8.h27': -0.000581115047680214,
#  'a8.h28': -0.0009604358347132802,
#  'a8.h30': 0.0008732003625482321,
#  'a8.h31': 0.003944834985304624,
#  'a9.h0': -0.0016760234721004963,
#  'a9.h1': 0.0020486141147557646,
#  'a9.h2': -0.00428295525489375,
#  'a9.h3': 0.0034446492791175842,
#  'a9.h4': -3.622530493885279e-05,
#  'a9.h5': 0.01646667515160516,
#  'a9.h6': 0.011077953153289855,
#  'a9.h7': 0.0008644154004286975,
#  'a9.h8': -0.0013668366591446102,
#  'a9.h9': 0.0015172063140198588,
#  'a9.h13': -0.000659288780298084,
#  'a9.h14': 0.0014732551935594529,
#  'a9.h15': 0.000504579278640449,
#  'a9.h22': -0.0005212778341956437,
#  'a9.h23': -0.0007887035608291626,
#  'a9.h24': 0.0004763086326420307,
#  'a9.h25': 0.0005072256899438798,
#  'a9.h26': -4.399730823934078e-05,
#  'a9.h27': 0.001043451949954033,
#  'a10.h0': -0.0007714863168075681,
#  'a10.h1': 0.002711453416850418,
#  'a10.h3': -0.00684298956184648,
#  'a10.h4': -0.0022307283070404083,
#  'a10.h5': 6.375514203682542e-05,
#  'a10.h7': 0.0018661912763491273,
#  'a10.h10': -0.0010351689998060465,
#  'a10.h12': 0.0006182148354128003,
#  'a10.h13': 0.0029838144255336374,
#  'a10.h14': -0.001586216501891613,
#  'a10.h15': -0.004645525332307443,
#  'a10.h17': 0.00029226200422272086,
#  'a10.h20': 0.0024483009765390307,
#  'a10.h22': -0.00273373001255095,
#  'a10.h23': 0.0016102991066873074,
#  'a10.h24': 0.0018419171101413667,
#  'a10.h25': 0.0013304714229889214,
#  'a10.h26': 0.0019913709547836334,
#  'a11.h2': 0.0018299623916391283,
#  'a11.h3': 0.00016432569827884436,
#  'a11.h4': 0.00021473568631336093,
#  'a11.h5': -0.0005095963133499026,
#  'a11.h8': 2.0404462702572346e-05,
#  'a11.h9': -0.0004996397765353322,
#  'a11.h11': -0.0006100826431065798,
#  'a11.h22': 0.00014151365030556917,
#  'a11.h23': -0.003183091786922887,
#  'a11.h30': 0.000543518690392375,
#  'a12.h1': 0.0008184595790226012,
#  'a12.h2': -0.00011572061339393258,
#  'a12.h4': -0.0021487229387275875,
#  'a12.h5': -0.0008006640709936619,
#  'a12.h6': -0.000505111354868859,
#  'a12.h7': 0.0007680757553316653,
#  'a12.h12': -0.0009869178174994886,
#  'a12.h13': 0.005043271026806906,
#  'a12.h15': -0.005484738270752132,
#  'a12.h18': 0.0005248580127954483,
#  'a12.h28': -0.00015901820734143257,
#  'a13.h0': -0.00015077105490490794,
#  'a13.h2': 0.0006458603602368385,
#  'a13.h4': -0.0003360253758728504,
#  'a13.h5': -0.0007195508223958313,
#  'a13.h6': -5.8505276683717966e-05,
#  'a13.h9': -0.0004989839508198202,
#  'a13.h13': 0.00267971633002162,
#  'a13.h16': 0.00010336984996683896,
#  'a13.h17': 0.00017532461788505316,
#  'a13.h18': -0.0008423087419942021,
#  'a13.h20': -0.0006022939342074096,
#  'a13.h23': -0.0001959246292244643,
#  'a13.h24': 0.0005768369301222265,
#  'a14.h4': 0.00014451541937887669,
#  'a14.h5': -0.0011305933876428753,
#  'a14.h6': -0.005505317938514054,
#  'a14.h7': 0.0004909375566057861,
#  'a14.h13': -0.0005622438038699329,
#  'a14.h14': 0.0002513706567697227,
#  'a14.h15': -0.0013539143255911767,
#  'a14.h20': -0.0016176545177586377,
#  'a14.h21': 2.5089771952480078e-05,
#  'a14.h22': -0.002551774145103991,
#  'a14.h30': 0.0005866901483386755,
#  'a14.h31': 0.0005713379359804094,
#  'a15.h0': 0.0018158114689867944,
#  'a15.h1': 0.002186208206694573,
#  'a15.h2': -0.002505002514226362,
#  'a15.h3': 0.0002632397518027574,
#  'a15.h5': -0.0014460670063272119,
#  'a15.h6': -0.0020232339447829872,
#  'a15.h12': -0.0006733172340318561,
#  'a15.h20': -0.0006642613443545997,
#  'a15.h28': 0.002126541920006275,
#  'a15.h29': 0.005683031427906826,
#  'a15.h30': -0.0006902887835167348,
#  'a15.h31': 0.0002851132012438029}

# %%
import torch

# Create a tensor to store the heatmap values
heatmap_tensor = torch.zeros((16, 32))  # Assuming a maximum of 16 layers and 32 heads

# Populate the tensor with values from heatmap_dict
for key, value in heatmap_dict.items():
    layer, head = map(int, key[1:].split('.h'))
    heatmap_tensor[layer, head] = value

heatmap_tensor
# Out:
# tensor([[ 0.0000e+00,  0.0000e+00,  2.1734e-03,  1.0811e-03,  0.0000e+00,
#           0.0000e+00,  1.1418e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  4.9028e-04,
#          -6.8333e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.5184e-03,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  7.9612e-04,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  8.2535e-04,
#           0.0000e+00,  0.0000e+00, -4.8666e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           1.1126e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00, -7.5997e-04,  0.0000e+00,  6.4542e-04,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.1085e-03,
#           5.5519e-04,  2.2937e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  7.3890e-04,
#           5.7828e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  4.7686e-04,  0.0000e+00,  0.0000e+00,
#          -5.1676e-04,  0.0000e+00, -5.5978e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-1.3482e-03,  1.2399e-04,  0.0000e+00,  0.0000e+00,  1.0873e-03,
#           0.0000e+00,  0.0000e+00,  1.0976e-03,  0.0000e+00,  5.8624e-04,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -5.7067e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-2.2833e-03, -6.8378e-04, -1.4266e-03,  1.3096e-03,  1.2134e-03,
#          -3.4780e-05,  5.9617e-04,  6.1119e-04,  0.0000e+00,  0.0000e+00,
#           5.6214e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00, -5.7769e-04,  0.0000e+00,  0.0000e+00,  1.2528e-03,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  4.9021e-04,  0.0000e+00,
#           0.0000e+00, -4.6485e-04,  0.0000e+00,  1.0558e-03,  1.3489e-03,
#           0.0000e+00,  0.0000e+00],
#         [ 3.2137e-03, -3.8249e-03,  0.0000e+00,  6.9228e-03, -1.7940e-03,
#          -4.1857e-03,  3.5899e-03,  4.0244e-03, -4.8587e-04, -9.8519e-04,
#           1.0778e-03,  0.0000e+00,  1.8000e-03,  0.0000e+00, -4.8626e-04,
#          -1.1743e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           5.7498e-04, -4.6962e-04, -2.7065e-03,  5.9507e-04,  0.0000e+00,
#           1.9526e-04,  0.0000e+00,  0.0000e+00,  3.0014e-03,  0.0000e+00,
#           0.0000e+00, -7.3977e-04],
#         [ 1.1773e-03,  1.6268e-03,  1.1673e-03,  5.9502e-04,  3.0744e-04,
#           4.5333e-03,  3.3465e-03, -2.0403e-03, -1.1835e-03,  5.8203e-05,
#           7.7510e-04,  2.9340e-03,  0.0000e+00,  4.8382e-04, -2.6849e-05,
#           0.0000e+00,  1.3981e-03,  1.6295e-05, -2.7202e-04,  3.4952e-05,
#           0.0000e+00,  0.0000e+00,  1.2993e-03, -5.4888e-04,  0.0000e+00,
#           7.4855e-04,  0.0000e+00,  0.0000e+00,  9.4368e-05,  5.1589e-04,
#          -2.1044e-03,  1.8548e-04],
#         [-2.6010e-03,  8.6495e-03,  1.3467e-02, -1.9661e-04, -2.2830e-03,
#           9.1196e-03,  1.1095e-03,  3.5005e-04,  0.0000e+00, -5.5465e-04,
#           9.9921e-04,  0.0000e+00,  0.0000e+00, -2.5914e-04, -5.5198e-04,
#          -8.7703e-04, -2.2075e-04,  0.0000e+00,  0.0000e+00,  6.4180e-04,
#          -1.3553e-03,  6.2261e-05, -4.7423e-04, -1.0446e-03,  5.8333e-04,
#           0.0000e+00,  0.0000e+00,  4.5453e-04,  6.1939e-04,  1.6448e-04,
#           0.0000e+00,  0.0000e+00],
#         [ 1.0283e-03,  9.1530e-03,  6.0087e-03, -9.6458e-04, -2.3422e-03,
#          -2.4427e-03,  5.7359e-03,  5.5950e-03,  0.0000e+00,  0.0000e+00,
#           7.4768e-04,  4.4292e-04, -4.6097e-03,  1.3317e-03,  4.8538e-04,
#           0.0000e+00,  0.0000e+00, -6.9408e-04,  0.0000e+00,  0.0000e+00,
#          -7.4557e-04,  2.5181e-03,  0.0000e+00,  0.0000e+00, -8.9616e-05,
#           0.0000e+00, -4.6625e-04, -5.8112e-04, -9.6044e-04,  0.0000e+00,
#           8.7320e-04,  3.9448e-03],
#         [-1.6760e-03,  2.0486e-03, -4.2830e-03,  3.4446e-03, -3.6225e-05,
#           1.6467e-02,  1.1078e-02,  8.6442e-04, -1.3668e-03,  1.5172e-03,
#           0.0000e+00,  0.0000e+00,  0.0000e+00, -6.5929e-04,  1.4733e-03,
#           5.0458e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -5.2128e-04, -7.8870e-04,  4.7631e-04,
#           5.0723e-04, -4.3997e-05,  1.0435e-03,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-7.7149e-04,  2.7115e-03,  0.0000e+00, -6.8430e-03, -2.2307e-03,
#           6.3755e-05,  0.0000e+00,  1.8662e-03,  0.0000e+00,  0.0000e+00,
#          -1.0352e-03,  0.0000e+00,  6.1821e-04,  2.9838e-03, -1.5862e-03,
#          -4.6455e-03,  0.0000e+00,  2.9226e-04,  0.0000e+00,  0.0000e+00,
#           2.4483e-03,  0.0000e+00, -2.7337e-03,  1.6103e-03,  1.8419e-03,
#           1.3305e-03,  1.9914e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  1.8300e-03,  1.6433e-04,  2.1474e-04,
#          -5.0960e-04,  0.0000e+00,  0.0000e+00,  2.0404e-05, -4.9964e-04,
#           0.0000e+00, -6.1008e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  1.4151e-04, -3.1831e-03,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           5.4352e-04,  0.0000e+00],
#         [ 0.0000e+00,  8.1846e-04, -1.1572e-04,  0.0000e+00, -2.1487e-03,
#          -8.0066e-04, -5.0511e-04,  7.6808e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -9.8692e-04,  5.0433e-03,  0.0000e+00,
#          -5.4847e-03,  0.0000e+00,  0.0000e+00,  5.2486e-04,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00, -1.5902e-04,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [-1.5077e-04,  0.0000e+00,  6.4586e-04,  0.0000e+00, -3.3603e-04,
#          -7.1955e-04, -5.8505e-05,  0.0000e+00,  0.0000e+00, -4.9898e-04,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  2.6797e-03,  0.0000e+00,
#           0.0000e+00,  1.0337e-04,  1.7532e-04, -8.4231e-04,  0.0000e+00,
#          -6.0229e-04,  0.0000e+00,  0.0000e+00, -1.9592e-04,  5.7684e-04,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.4452e-04,
#          -1.1306e-03, -5.5053e-03,  4.9094e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00, -5.6224e-04,  2.5137e-04,
#          -1.3539e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          -1.6177e-03,  2.5090e-05, -2.5518e-03,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           5.8669e-04,  5.7134e-04],
#         [ 1.8158e-03,  2.1862e-03, -2.5050e-03,  2.6324e-04,  0.0000e+00,
#          -1.4461e-03, -2.0232e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -6.7332e-04,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          -6.6426e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  2.1265e-03,  5.6830e-03,
#          -6.9029e-04,  2.8511e-04]])

# %%
import torch
import plotly.graph_objects as go
from plotly.subplots import make_subplots

tensor1 = act_patching_tensor
tensor2 = heatmap_tensor

fig = make_subplots(
    rows=1, cols=2,
    horizontal_spacing=0.05, 
    subplot_titles=("", ""),
)

# Left heatmap
fig.add_trace(
    go.Heatmap(
        z=tensor1.numpy(),
        colorscale="RdBu",
        zmid=0,
        showscale=True,
        colorbar=dict(
            title="",
            thickness=20,
            # Position the left colorbar a bit to the right of the left domain
            x=0.46,        # 0 = far left, 1 = far right
            xanchor="left"
        ),
    ),
    row=1, col=1
)

# Right heatmap
fig.add_trace(
    go.Heatmap(
        z=tensor2.numpy(),
        colorscale="RdBu",
        zmid=0,
        showscale=True,
        colorbar=dict(
            title="",
            thickness=20,
            # Place the right colorbar well to the right
            x=1.01,
            xanchor="left"
        ),
    ),
    row=1, col=2
)

# -- Make the left subplot narrower and shifted left
fig.update_xaxes(domain=[0.0, 0.45], row=1, col=1)  # 30% of total width
# -- Shift the right subplot further right
fig.update_xaxes(domain=[0.55, 1.0], row=1, col=2) # starts at 0.45, ends at 0.8

fig.update_yaxes(title_text="Layer", row=1, col=1)
fig.update_yaxes(title_text="Layer", row=1, col=2)
fig.update_xaxes(title_text="Head", row=1, col=1)
fig.update_xaxes(title_text="Head", row=1, col=2)
fig.update_yaxes(autorange="reversed", row=1, col=1)
fig.update_yaxes(autorange="reversed", row=1, col=2)

fig.update_layout(
    width=1500,                # <--- Force a smaller figure width in pixels
    height=500,
    font=dict(size=14)
)
fig.show()

# %%
fig.write_image("bias_heatmap.svg")

# %% [markdown]
# ### Toxicity heatmaps

# %%
# Specify the path to the .pth file
pth_file_path = 'final_toxicity_tensor_0.pth'

# Load the tensor from the .pth file
act_patching_tensor = torch.load(pth_file_path, map_location=torch.device('cpu'))
act_patching_tensor.requires_grad = False
# Print the loaded tensor
act_patching_tensor.shape
# Out:
# /var/folders/ts/2_ky83950p3_q8mq0075gb1c0000gn/T/ipykernel_12090/1436813712.py:5: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# torch.Size([16, 32])

# %%
graph_path = "./toxicity_EAP_step12000_11853edges.json"

g = Graph.from_json(graph_path)

# %%
import pandas as pd

heatmap_dict = dict()

for node_str in g.nodes:
    node = g.nodes[node_str]
    if node.in_graph and "a" in node_str:
        print(node)
        heatmap_dict[node_str] = 0
        for p_edge in node.parent_edges:
            if p_edge.in_graph:
                heatmap_dict[node_str] += p_edge.score
                print(p_edge)
                print(p_edge.parent)
                print(p_edge.child)
        for c_edge in node.child_edges:
            if c_edge.in_graph:
                pass
                # print(c_edge)
                # print(c_edge.parent)
                # print(c_edge.child)

heatmap_dict
# Out:
# Node(a0.h0, in_graph: True)
# Edge(input->a0.h0<k>, score: 0.022330591455101967, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h0, in_graph: True)
# Edge(input->a0.h0<q>, score: 0.0007328155334107578, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h0, in_graph: True)
# Edge(input->a0.h0<v>, score: -0.0005695744184777141, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a0.h1, in_graph: True)
# Edge(input->a0.h1<q>, score: -0.0009942230535671115, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h1, in_graph: True)
# Edge(input->a0.h1<k>, score: -0.00830574706196785, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h1, in_graph: True)
# Edge(input->a0.h1<v>, score: 0.0010062727378681302, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h1, in_graph: True)
# Node(a0.h2, in_graph: True)
# Edge(input->a0.h2<q>, score: -0.0060812318697571754, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h2, in_graph: True)
# Edge(input->a0.h2<k>, score: -0.011140699498355389, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h2, in_graph: True)
# Edge(input->a0.h2<v>, score: 0.00062655407236889, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a0.h3, in_graph: True)
# Edge(input->a0.h3<v>, score: -0.0009348567691631615, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h3, in_graph: True)
# Edge(input->a0.h3<k>, score: -0.005976606160402298, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h3, in_graph: True)
# Edge(input->a0.h3<q>, score: -0.0011671273969113827, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h3, in_graph: True)
# Node(a0.h4, in_graph: True)
# Edge(input->a0.h4<q>, score: 0.002489696955308318, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h4, in_graph: True)
# Edge(input->a0.h4<k>, score: 0.004729513078927994, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h4, in_graph: True)
# Edge(input->a0.h4<v>, score: 0.001938247005455196, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h4, in_graph: True)
# Node(a0.h5, in_graph: True)
# Edge(input->a0.h5<q>, score: -0.0012654786696657538, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h5, in_graph: True)
# Edge(input->a0.h5<v>, score: -0.001118755666539073, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h5, in_graph: True)
# Edge(input->a0.h5<k>, score: -0.007417450193315744, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h5, in_graph: True)
# Node(a0.h6, in_graph: True)
# Edge(input->a0.h6<q>, score: 0.0007862655911594629, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h6, in_graph: True)
# Edge(input->a0.h6<k>, score: -0.009388862177729607, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h6, in_graph: True)
# Edge(input->a0.h6<v>, score: 0.003470298368483782, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h6, in_graph: True)
# Node(a0.h7, in_graph: True)
# Edge(input->a0.h7<v>, score: 0.003462378866970539, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h7, in_graph: True)
# Edge(input->a0.h7<k>, score: -0.002685651183128357, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h7, in_graph: True)
# Edge(input->a0.h7<q>, score: 0.005688794422894716, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a0.h8, in_graph: True)
# Edge(input->a0.h8<q>, score: 0.001052121282555163, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h8, in_graph: True)
# Node(a0.h9, in_graph: True)
# Edge(input->a0.h9<q>, score: 0.0026952028274536133, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a0.h10, in_graph: True)
# Edge(input->a0.h10<q>, score: 0.0014006445417180657, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a0.h11, in_graph: True)
# Edge(input->a0.h11<q>, score: -0.0010506869293749332, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a0.h12, in_graph: True)
# Edge(input->a0.h12<q>, score: -0.002224645344540477, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h12, in_graph: True)
# Node(a0.h13, in_graph: True)
# Edge(input->a0.h13<q>, score: 0.0057983361184597015, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h13, in_graph: True)
# Node(a0.h14, in_graph: True)
# Edge(input->a0.h14<q>, score: -0.000484858377603814, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h14, in_graph: True)
# Node(a0.h15, in_graph: True)
# Edge(input->a0.h15<q>, score: -0.003959375433623791, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h15, in_graph: True)
# Node(a0.h16, in_graph: True)
# Edge(input->a0.h16<q>, score: 0.000522392860148102, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h16, in_graph: True)
# Node(a0.h17, in_graph: True)
# Edge(input->a0.h17<q>, score: 0.0011023316765204072, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a0.h18, in_graph: True)
# Edge(input->a0.h18<q>, score: -0.004075650125741959, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h18, in_graph: True)
# Node(a0.h19, in_graph: True)
# Edge(input->a0.h19<q>, score: 0.0007447243551723659, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h19, in_graph: True)
# Node(a0.h20, in_graph: True)
# Edge(input->a0.h20<q>, score: -0.003921865951269865, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a0.h22, in_graph: True)
# Edge(input->a0.h22<q>, score: 0.00457946490496397, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h22, in_graph: True)
# Node(a0.h24, in_graph: True)
# Edge(input->a0.h24<q>, score: -0.000793035258539021, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a0.h27, in_graph: True)
# Edge(input->a0.h27<q>, score: -0.001701776753179729, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h27, in_graph: True)
# Node(a0.h28, in_graph: True)
# Edge(input->a0.h28<q>, score: 0.0011482920963317156, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h28, in_graph: True)
# Node(a0.h30, in_graph: True)
# Edge(input->a0.h30<q>, score: -0.00509767746552825, in_graph: True)
# Node(input, in_graph: True)
# Node(a0.h30, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h24->a1.h0<v>, score: -0.000527527357917279, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h9->a1.h0<v>, score: 0.0011412011226639152, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h7->a1.h0<v>, score: 0.001278716721571982, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(m0->a1.h0<v>, score: -0.0024119431618601084, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h5->a1.h0<v>, score: 0.0005127110052853823, in_graph: True)
# Node(a0.h5, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h10->a1.h0<v>, score: -0.0008004102855920792, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h0->a1.h0<k>, score: 0.0013291342183947563, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(input->a1.h0<q>, score: 0.0011063574347645044, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h12->a1.h0<v>, score: -0.0007721164147369564, in_graph: True)
# Node(a0.h12, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h20->a1.h0<v>, score: -0.00047167143202386796, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h28->a1.h0<v>, score: -0.0004913656157441437, in_graph: True)
# Node(a0.h28, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(input->a1.h0<v>, score: -0.002072479110211134, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h0->a1.h0<v>, score: -0.0009010981884784997, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(input->a1.h0<k>, score: -0.0028035950381308794, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h17->a1.h0<v>, score: -0.001120094326324761, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h2->a1.h0<v>, score: 0.001508738729171455, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h17->a1.h0<k>, score: 0.0013733385130763054, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h4->a1.h0<v>, score: -0.00047135911881923676, in_graph: True)
# Node(a0.h4, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h16->a1.h0<v>, score: 0.0006230565486475825, in_graph: True)
# Node(a0.h16, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h6->a1.h0<v>, score: -0.0006252519669942558, in_graph: True)
# Node(a0.h6, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h9->a1.h0<k>, score: 0.0005462963599711657, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(m0->a1.h0<k>, score: -0.003052162704989314, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(m0->a1.h0<q>, score: 0.0018072703387588263, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h0, in_graph: True)
# Edge(a0.h2->a1.h0<k>, score: 0.002268425654619932, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(m0->a1.h1<v>, score: 0.000691440305672586, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(a0.h2->a1.h1<q>, score: 0.000746331934351474, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(a0.h17->a1.h1<q>, score: -0.0005999230197630823, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(a0.h0->a1.h1<q>, score: -0.0008610999793745577, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(input->a1.h1<q>, score: 0.0005870023160241544, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(m0->a1.h1<q>, score: 0.0012917540734633803, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(input->a1.h1<k>, score: 0.0015250717988237739, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h1, in_graph: True)
# Edge(input->a1.h1<v>, score: -0.0007947119884192944, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h1, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h18->a1.h2<v>, score: -0.0006234186002984643, in_graph: True)
# Node(a0.h18, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h0->a1.h2<v>, score: 0.0035345868673175573, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h20->a1.h2<v>, score: 0.0012356560910120606, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(m0->a1.h2<q>, score: 0.00095846236217767, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h1->a1.h2<v>, score: -0.0021342304535210133, in_graph: True)
# Node(a0.h1, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h17->a1.h2<k>, score: 0.0005511256167665124, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h15->a1.h2<v>, score: -0.0009692514431662858, in_graph: True)
# Node(a0.h15, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(input->a1.h2<k>, score: 0.003643938573077321, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h28->a1.h2<v>, score: 0.0011495412327349186, in_graph: True)
# Node(a0.h28, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h7->a1.h2<v>, score: -0.0008765583042986691, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h2->a1.h2<k>, score: 0.001093730446882546, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(m0->a1.h2<k>, score: 0.009629976004362106, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(input->a1.h2<v>, score: -0.0061304932460188866, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h24->a1.h2<v>, score: -0.0010761396260932088, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h8->a1.h2<v>, score: -0.0008373067248612642, in_graph: True)
# Node(a0.h8, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h0->a1.h2<k>, score: 0.000908781192265451, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h3->a1.h2<v>, score: -0.0006202946533448994, in_graph: True)
# Node(a0.h3, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h2->a1.h2<v>, score: -0.0020431189332157373, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(m0->a1.h2<v>, score: -0.010973973199725151, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h10->a1.h2<v>, score: -0.001967634307220578, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h13->a1.h2<v>, score: 0.0007106821285560727, in_graph: True)
# Node(a0.h13, in_graph: True)
# Node(a1.h2, in_graph: True)
# Edge(a0.h17->a1.h2<v>, score: 0.0025261074770241976, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h2, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(input->a1.h3<k>, score: -0.0030891788192093372, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(m0->a1.h3<k>, score: -0.007865485735237598, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h4->a1.h3<k>, score: 0.0004875187296420336, in_graph: True)
# Node(a0.h4, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h0->a1.h3<q>, score: -0.0007796473219059408, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h9->a1.h3<k>, score: 0.0005631927633658051, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h0->a1.h3<v>, score: 0.0006074972334317863, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(m0->a1.h3<q>, score: -0.002646037843078375, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(input->a1.h3<v>, score: -0.0004790297825820744, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h3->a1.h3<v>, score: 0.0005268176319077611, in_graph: True)
# Node(a0.h3, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(a0.h14->a1.h3<k>, score: -0.000693708483595401, in_graph: True)
# Node(a0.h14, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(m0->a1.h3<v>, score: -0.001011006417684257, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h3, in_graph: True)
# Edge(input->a1.h3<q>, score: 0.0008034282363951206, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h20->a1.h4<k>, score: 0.0004951664595864713, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h7->a1.h4<k>, score: -0.0005573942326009274, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h10->a1.h4<v>, score: -0.0008976234239526093, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(m0->a1.h4<q>, score: -0.004265997558832169, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h7->a1.h4<v>, score: -0.000483140378491953, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h2->a1.h4<k>, score: 0.004301860462874174, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h15->a1.h4<k>, score: -0.0004975005867891014, in_graph: True)
# Node(a0.h15, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h28->a1.h4<k>, score: 0.0013795254053547978, in_graph: True)
# Node(a0.h28, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h22->a1.h4<k>, score: -0.0016907629324123263, in_graph: True)
# Node(a0.h22, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h30->a1.h4<k>, score: 0.0012069001095369458, in_graph: True)
# Node(a0.h30, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(input->a1.h4<q>, score: -0.0008843452669680119, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h17->a1.h4<k>, score: 0.001979645574465394, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h16->a1.h4<k>, score: -0.0010693748481571674, in_graph: True)
# Node(a0.h16, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(m0->a1.h4<v>, score: -0.006888461299240589, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h0->a1.h4<k>, score: 0.0022844807244837284, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h9->a1.h4<k>, score: 0.0007912698201835155, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h12->a1.h4<v>, score: -0.00048340141074731946, in_graph: True)
# Node(a0.h12, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(m0->a1.h4<k>, score: 0.014353472739458084, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(input->a1.h4<v>, score: 0.01014579925686121, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h10->a1.h4<k>, score: 0.0006557744927704334, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h11->a1.h4<v>, score: -0.0004785284399986267, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h1->a1.h4<k>, score: -0.0010964944958686829, in_graph: True)
# Node(a0.h1, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h14->a1.h4<k>, score: 0.0006609472329728305, in_graph: True)
# Node(a0.h14, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h4->a1.h4<k>, score: 0.000573699246160686, in_graph: True)
# Node(a0.h4, in_graph: True)
# Node(a1.h4, in_graph: True)
# Edge(a0.h20->a1.h4<v>, score: 0.0005040174000896513, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h4, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(a0.h24->a1.h5<k>, score: 0.0005883417325094342, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(a0.h9->a1.h5<k>, score: 0.000549700518604368, in_graph: True)
# Node(a0.h9, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(a0.h10->a1.h5<v>, score: -0.0005175521364435554, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(a0.h2->a1.h5<v>, score: 0.0010367074282839894, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(input->a1.h5<v>, score: -0.0009895946132019162, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(m0->a1.h5<k>, score: 0.020575378090143204, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(m0->a1.h5<q>, score: -0.0010132202878594398, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(m0->a1.h5<v>, score: 0.005123666953295469, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h5, in_graph: True)
# Edge(a0.h7->a1.h5<k>, score: 0.0006113239796832204, in_graph: True)
# Node(a0.h7, in_graph: True)
# Node(a1.h5, in_graph: True)
# Node(a1.h6, in_graph: True)
# Edge(input->a1.h6<v>, score: 0.0016237307572737336, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h6, in_graph: True)
# Edge(m0->a1.h6<k>, score: -0.01328052207827568, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h6, in_graph: True)
# Edge(m0->a1.h6<v>, score: 0.003077280707657337, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h6, in_graph: True)
# Edge(m0->a1.h6<q>, score: -0.0034860961604863405, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h6, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(m0->a1.h7<q>, score: 0.0012159154284745455, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(a0.h0->a1.h7<v>, score: -0.0013886127853766084, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(m0->a1.h7<k>, score: 0.0019894721917808056, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(m0->a1.h7<v>, score: -0.0019417947623878717, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(a0.h17->a1.h7<v>, score: -0.000675684423185885, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(a0.h10->a1.h7<v>, score: 0.0009898708667606115, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(a0.h2->a1.h7<v>, score: -0.0010689665796235204, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(input->a1.h7<v>, score: 0.003766651265323162, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h7, in_graph: True)
# Edge(input->a1.h7<k>, score: -0.0005340785137377679, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h7, in_graph: True)
# Node(a1.h8, in_graph: True)
# Edge(a0.h17->a1.h8<q>, score: 0.0009206290123984218, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a1.h9, in_graph: True)
# Edge(input->a1.h9<q>, score: -0.0008712738053873181, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h9, in_graph: True)
# Edge(m0->a1.h9<q>, score: -0.002324800007045269, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h9, in_graph: True)
# Node(a1.h10, in_graph: True)
# Edge(input->a1.h10<q>, score: 0.0016422003973275423, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h10, in_graph: True)
# Edge(m0->a1.h10<q>, score: 0.006692974828183651, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a1.h11, in_graph: True)
# Edge(m0->a1.h11<q>, score: 0.003661204595118761, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h11, in_graph: True)
# Edge(input->a1.h11<q>, score: 0.0009757415391504765, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h11, in_graph: True)
# Edge(a0.h2->a1.h11<q>, score: 0.0006869480712339282, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a1.h12, in_graph: True)
# Edge(m0->a1.h12<q>, score: -0.0023244619369506836, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h12, in_graph: True)
# Node(a1.h13, in_graph: True)
# Edge(m0->a1.h13<q>, score: 0.0012307486031204462, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h13, in_graph: True)
# Node(a1.h14, in_graph: True)
# Edge(m0->a1.h14<q>, score: 0.0012242525117471814, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h14, in_graph: True)
# Node(a1.h15, in_graph: True)
# Edge(input->a1.h15<q>, score: 0.0006284150294959545, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h15, in_graph: True)
# Node(a1.h16, in_graph: True)
# Edge(a0.h24->a1.h16<q>, score: 0.0004901060019619763, in_graph: True)
# Node(a0.h24, in_graph: True)
# Node(a1.h16, in_graph: True)
# Edge(a0.h2->a1.h16<q>, score: -0.0008918261155486107, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h16, in_graph: True)
# Edge(m0->a1.h16<q>, score: 0.0012830885825678706, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h16, in_graph: True)
# Edge(input->a1.h16<q>, score: 0.0004581750836223364, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h16, in_graph: True)
# Edge(a0.h10->a1.h16<q>, score: -0.0005771663854829967, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a1.h17, in_graph: True)
# Edge(a0.h20->a1.h17<q>, score: -0.0005956131499260664, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h17, in_graph: True)
# Edge(m0->a1.h17<q>, score: -0.006753553636372089, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h17, in_graph: True)
# Edge(a0.h0->a1.h17<q>, score: -0.0006678667850792408, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h17, in_graph: True)
# Node(a1.h18, in_graph: True)
# Edge(input->a1.h18<q>, score: -0.002007728209719062, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h18, in_graph: True)
# Edge(m0->a1.h18<q>, score: -0.004074255935847759, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h18, in_graph: True)
# Node(a1.h19, in_graph: True)
# Edge(m0->a1.h19<q>, score: -0.0009006519103422761, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h19, in_graph: True)
# Edge(input->a1.h19<q>, score: 0.0015412915963679552, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h19, in_graph: True)
# Node(a1.h20, in_graph: True)
# Edge(input->a1.h20<q>, score: 0.0004905304522253573, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a1.h21, in_graph: True)
# Edge(m0->a1.h21<q>, score: -0.005612482316792011, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h21, in_graph: True)
# Edge(a0.h10->a1.h21<q>, score: -0.000509423844050616, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h21, in_graph: True)
# Node(a1.h22, in_graph: True)
# Edge(a0.h0->a1.h22<q>, score: -0.0009692173916846514, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a1.h22, in_graph: True)
# Edge(input->a1.h22<q>, score: -0.0013140715891495347, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h22, in_graph: True)
# Edge(m0->a1.h22<q>, score: -0.0006021221051923931, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h22, in_graph: True)
# Edge(a0.h11->a1.h22<q>, score: -0.0006630477146245539, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a1.h22, in_graph: True)
# Edge(a0.h20->a1.h22<q>, score: 0.0006751421606168151, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h22, in_graph: True)
# Node(a1.h23, in_graph: True)
# Edge(a0.h10->a1.h23<q>, score: -0.0005924211000092328, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a1.h23, in_graph: True)
# Edge(m0->a1.h23<q>, score: 0.019490117207169533, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h23, in_graph: True)
# Edge(a0.h2->a1.h23<q>, score: 0.0010215616784989834, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a1.h23, in_graph: True)
# Edge(input->a1.h23<q>, score: 0.0017689450178295374, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h23, in_graph: True)
# Node(a1.h24, in_graph: True)
# Edge(m0->a1.h24<q>, score: -0.0005449035088531673, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h24, in_graph: True)
# Edge(input->a1.h24<q>, score: -0.0012193442089483142, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h24, in_graph: True)
# Node(a1.h25, in_graph: True)
# Edge(a0.h11->a1.h25<q>, score: 0.0005151493824087083, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a1.h25, in_graph: True)
# Edge(a0.h20->a1.h25<q>, score: -0.0011333230650052428, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a1.h25, in_graph: True)
# Edge(m0->a1.h25<q>, score: -0.016668083146214485, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h25, in_graph: True)
# Edge(input->a1.h25<q>, score: -0.0027792835608124733, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h25, in_graph: True)
# Node(a1.h26, in_graph: True)
# Edge(m0->a1.h26<q>, score: -0.0011349458945915103, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h26, in_graph: True)
# Node(a1.h27, in_graph: True)
# Edge(m0->a1.h27<q>, score: 0.0008367321570403874, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h27, in_graph: True)
# Node(a1.h28, in_graph: True)
# Edge(m0->a1.h28<q>, score: -0.00148494029417634, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h28, in_graph: True)
# Edge(input->a1.h28<q>, score: 0.001042051357217133, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a1.h29, in_graph: True)
# Edge(m0->a1.h29<q>, score: -0.0018828785978257656, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h29, in_graph: True)
# Edge(input->a1.h29<q>, score: -0.0010391694959253073, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a1.h30, in_graph: True)
# Edge(input->a1.h30<q>, score: -0.0009368420578539371, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h30, in_graph: True)
# Edge(m0->a1.h30<q>, score: -0.002442001597955823, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h30, in_graph: True)
# Node(a1.h31, in_graph: True)
# Edge(input->a1.h31<q>, score: 0.0021691478323191404, in_graph: True)
# Node(input, in_graph: True)
# Node(a1.h31, in_graph: True)
# Edge(m0->a1.h31<q>, score: 0.005656164605170488, in_graph: True)
# Node(m0, in_graph: True)
# Node(a1.h31, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(input->a2.h0<k>, score: -0.0005791825242340565, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(a1.h28->a2.h0<v>, score: -0.0004915145109407604, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(m1->a2.h0<v>, score: 0.0012892737286165357, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(m1->a2.h0<k>, score: -0.004308105446398258, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(m0->a2.h0<k>, score: -0.0034946512896567583, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h0, in_graph: True)
# Edge(input->a2.h0<v>, score: 0.0010976011399179697, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h10->a2.h1<q>, score: -0.0006039290456101298, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h18->a2.h1<v>, score: 0.0010116893099620938, in_graph: True)
# Node(a1.h18, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h19->a2.h1<v>, score: 0.0006375085795298219, in_graph: True)
# Node(a1.h19, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h30->a2.h1<k>, score: -0.0006432408699765801, in_graph: True)
# Node(a1.h30, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h29->a2.h1<v>, score: 0.0006680708029307425, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h25->a2.h1<v>, score: 0.0006912557873874903, in_graph: True)
# Node(a1.h25, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h3->a2.h1<v>, score: -0.0022432541009038687, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m1->a2.h1<q>, score: 0.0018622768111526966, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h23->a2.h1<v>, score: -0.0012674129102379084, in_graph: True)
# Node(a1.h23, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h16->a2.h1<v>, score: 0.0005754933808930218, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h26->a2.h1<v>, score: 0.0006083764601498842, in_graph: True)
# Node(a1.h26, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(input->a2.h1<v>, score: 0.0013311004731804132, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(input->a2.h1<k>, score: -0.0016923731891438365, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h21->a2.h1<v>, score: 0.00054577412083745, in_graph: True)
# Node(a1.h21, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h23->a2.h1<k>, score: -0.0004961383529007435, in_graph: True)
# Node(a1.h23, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m0->a2.h1<q>, score: 0.0005637506255879998, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a0.h0->a2.h1<v>, score: -0.0009713203180581331, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h10->a2.h1<k>, score: 0.0017510858597233891, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m1->a2.h1<k>, score: -0.005914423614740372, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a0.h8->a2.h1<v>, score: 0.000609656039159745, in_graph: True)
# Node(a0.h8, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m0->a2.h1<k>, score: -0.001370422774925828, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m1->a2.h1<v>, score: 0.000899279024451971, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(m0->a2.h1<v>, score: 0.0006049624062143266, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h28->a2.h1<v>, score: -0.003088461235165596, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h28->a2.h1<k>, score: -0.0011370143620297313, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h10->a2.h1<v>, score: 0.0018595732981339097, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a0.h20->a2.h1<v>, score: -0.000500129594001919, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h0->a2.h1<v>, score: 0.003063201904296875, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h8->a2.h1<v>, score: 0.0017081624828279018, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a0.h17->a2.h1<v>, score: -0.0016023358330130577, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h24->a2.h1<v>, score: 0.0006755565409548581, in_graph: True)
# Node(a1.h24, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h11->a2.h1<k>, score: -0.0007656927919015288, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h31->a2.h1<k>, score: 0.0006503471522592008, in_graph: True)
# Node(a1.h31, in_graph: True)
# Node(a2.h1, in_graph: True)
# Edge(a1.h20->a2.h1<v>, score: 0.000557917810510844, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h1, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m0->a2.h2<v>, score: 0.0016795126721262932, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m1->a2.h2<q>, score: -0.002464215038344264, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m1->a2.h2<v>, score: -0.0008029146702028811, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(a1.h10->a2.h2<q>, score: -0.0005224522901698947, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(a1.h8->a2.h2<q>, score: -0.0005556363030336797, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(a1.h18->a2.h2<q>, score: -0.0004613906203303486, in_graph: True)
# Node(a1.h18, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m0->a2.h2<k>, score: -0.0014950309414416552, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m1->a2.h2<k>, score: -0.001567141734994948, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(m0->a2.h2<q>, score: -0.0035781231708824635, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h2, in_graph: True)
# Edge(input->a2.h2<q>, score: -0.0020079908426851034, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h2, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a0.h0->a2.h3<k>, score: 0.0009215842583216727, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h0->a2.h3<k>, score: -0.0008217057911679149, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h8->a2.h3<v>, score: -0.0006996408337727189, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(input->a2.h3<k>, score: 0.0016963058151304722, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h1->a2.h3<v>, score: 0.0005028907908126712, in_graph: True)
# Node(a1.h1, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m0->a2.h3<q>, score: 0.0004827493103221059, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(input->a2.h3<v>, score: -0.0009769508615136147, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h30->a2.h3<v>, score: 0.000613079231698066, in_graph: True)
# Node(a1.h30, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m1->a2.h3<q>, score: 0.0009318065131083131, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m0->a2.h3<v>, score: -0.005690249614417553, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a0.h17->a2.h3<k>, score: 0.0006521350587718189, in_graph: True)
# Node(a0.h17, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h10->a2.h3<q>, score: 0.0004729894862975925, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a0.h2->a2.h3<v>, score: 0.0005333926528692245, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m1->a2.h3<k>, score: -0.00048510776832699776, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m0->a2.h3<k>, score: -0.0035243581514805555, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h10->a2.h3<k>, score: -0.0006098334561102092, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h29->a2.h3<k>, score: 0.000510638696141541, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h8->a2.h3<q>, score: -0.0005095053929835558, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a0.h2->a2.h3<k>, score: 0.0015605600783601403, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h11->a2.h3<k>, score: 0.000549948716070503, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h1->a2.h3<k>, score: 0.0012772532645612955, in_graph: True)
# Node(a1.h1, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(m1->a2.h3<v>, score: 0.003738313214853406, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h3, in_graph: True)
# Edge(a1.h16->a2.h3<k>, score: 0.0005683533381670713, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a2.h3, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h10->a2.h4<q>, score: -0.002034717472270131, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h10->a2.h4<v>, score: 0.0005410570884123445, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h30->a2.h4<v>, score: -0.0005036408547312021, in_graph: True)
# Node(a1.h30, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m1->a2.h4<k>, score: -0.004254823084920645, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h28->a2.h4<v>, score: -0.002286117058247328, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h12->a2.h4<v>, score: -0.0005979456473141909, in_graph: True)
# Node(a1.h12, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h10->a2.h4<k>, score: 0.0006668608402833343, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m0->a2.h4<v>, score: 0.0015294370241463184, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h29->a2.h4<q>, score: 0.0006554927094839513, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h3->a2.h4<v>, score: -0.0005542379803955555, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m0->a2.h4<k>, score: -0.00246093375608325, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a0.h20->a2.h4<q>, score: -0.0004801879113074392, in_graph: True)
# Node(a0.h20, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h16->a2.h4<v>, score: -0.0006625506794080138, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h11->a2.h4<v>, score: -0.0013603006955236197, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m1->a2.h4<v>, score: 0.0010866181692108512, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a0.h11->a2.h4<v>, score: 0.0005021814722567797, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h31->a2.h4<v>, score: 0.0011288294335827231, in_graph: True)
# Node(a1.h31, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(input->a2.h4<k>, score: 0.0005919282557442784, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h8->a2.h4<q>, score: -0.0005471227923408151, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m1->a2.h4<q>, score: -0.0028145986143499613, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h1->a2.h4<v>, score: 0.0005726716481149197, in_graph: True)
# Node(a1.h1, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(a1.h29->a2.h4<v>, score: -0.0010516984621062875, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h4, in_graph: True)
# Edge(m0->a2.h4<q>, score: -0.0011121740099042654, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h4, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(input->a2.h5<v>, score: 0.0023612368386238813, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h10->a2.h5<v>, score: 0.0014320079935714602, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a0.h11->a2.h5<q>, score: -0.000540266977623105, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h28->a2.h5<q>, score: -0.0006339787505567074, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h5->a2.h5<q>, score: 0.00045518114347942173, in_graph: True)
# Node(a1.h5, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a0.h2->a2.h5<k>, score: -0.0007084276876412332, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h30->a2.h5<q>, score: -0.0005046139121986926, in_graph: True)
# Node(a1.h30, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h31->a2.h5<q>, score: 0.0007581412210129201, in_graph: True)
# Node(a1.h31, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m1->a2.h5<v>, score: -0.0018935255939140916, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h28->a2.h5<v>, score: 0.0009112391853705049, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(input->a2.h5<q>, score: -0.0006069838418625295, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m0->a2.h5<q>, score: -0.0055271233431994915, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h20->a2.h5<k>, score: -0.0020812295842915773, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h11->a2.h5<v>, score: -0.0006185658276081085, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m1->a2.h5<q>, score: -0.006456684321165085, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(a1.h0->a2.h5<v>, score: 0.0009608721593394876, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m1->a2.h5<k>, score: 0.001610074075870216, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h5, in_graph: True)
# Edge(m0->a2.h5<k>, score: 0.0013608598383143544, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h5, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a0.h0->a2.h6<v>, score: -0.00048807126586325467, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h20->a2.h6<v>, score: -0.00109170435462147, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m1->a2.h6<v>, score: 0.002401843899860978, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(input->a2.h6<k>, score: 0.0009017298580147326, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h0->a2.h6<v>, score: -0.0004566091811284423, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h17->a2.h6<v>, score: 0.0006918212748132646, in_graph: True)
# Node(a1.h17, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m1->a2.h6<q>, score: 0.006519561167806387, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h8->a2.h6<v>, score: 0.0006344784633256495, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(input->a2.h6<v>, score: 0.000506439246237278, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a0.h11->a2.h6<q>, score: 0.0006309851887635887, in_graph: True)
# Node(a0.h11, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h29->a2.h6<q>, score: 0.0010964954271912575, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h28->a2.h6<q>, score: -0.0014573844382539392, in_graph: True)
# Node(a1.h28, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m0->a2.h6<q>, score: 0.004528474062681198, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h11->a2.h6<v>, score: -0.0005280709592625499, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h8->a2.h6<q>, score: -0.0004708750348072499, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m1->a2.h6<k>, score: -0.0005034719360992312, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h10->a2.h6<k>, score: 0.0034064208157360554, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a0.h3->a2.h6<k>, score: 0.0006906238268129528, in_graph: True)
# Node(a0.h3, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h0->a2.h6<k>, score: 0.0007893762667663395, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h8->a2.h6<k>, score: 0.0012571506667882204, in_graph: True)
# Node(a1.h8, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h3->a2.h6<v>, score: 0.0007247418980114162, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h20->a2.h6<k>, score: 0.007652120664715767, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h24->a2.h6<q>, score: 0.0004519764333963394, in_graph: True)
# Node(a1.h24, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(m0->a2.h6<k>, score: -0.005397371016442776, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h11->a2.h6<k>, score: -0.0027066131588071585, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h29->a2.h6<k>, score: -0.0011423641117289662, in_graph: True)
# Node(a1.h29, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a0.h2->a2.h6<v>, score: -0.0026758715976029634, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(input->a2.h6<q>, score: 0.0008680394385010004, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a0.h2->a2.h6<k>, score: 0.0006042335880920291, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h6, in_graph: True)
# Edge(a1.h16->a2.h6<v>, score: 0.0010624706046655774, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a2.h6, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h20->a2.h7<k>, score: 0.0016915960004553199, in_graph: True)
# Node(a1.h20, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(m0->a2.h7<k>, score: 0.001695401268079877, in_graph: True)
# Node(m0, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h11->a2.h7<v>, score: -0.0005079502589069307, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a0.h10->a2.h7<k>, score: -0.0008095542434602976, in_graph: True)
# Node(a0.h10, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(m1->a2.h7<k>, score: 0.00258110323920846, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(m1->a2.h7<v>, score: 0.0010590978199616075, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a0.h2->a2.h7<k>, score: 0.0008106202003546059, in_graph: True)
# Node(a0.h2, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h10->a2.h7<q>, score: 0.0012280178489163518, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(input->a2.h7<q>, score: 0.001501183258369565, in_graph: True)
# Node(input, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h25->a2.h7<k>, score: -0.0005921109695918858, in_graph: True)
# Node(a1.h25, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h31->a2.h7<q>, score: 0.0004709193017333746, in_graph: True)
# Node(a1.h31, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h0->a2.h7<k>, score: 0.0007014953880570829, in_graph: True)
# Node(a1.h0, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a0.h0->a2.h7<k>, score: 0.0006461988086812198, in_graph: True)
# Node(a0.h0, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h11->a2.h7<k>, score: 0.000515527615789324, in_graph: True)
# Node(a1.h11, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h18->a2.h7<v>, score: -0.0006777882808819413, in_graph: True)
# Node(a1.h18, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h23->a2.h7<k>, score: 0.001178632490336895, in_graph: True)
# Node(a1.h23, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h10->a2.h7<k>, score: 0.0012436971301212907, in_graph: True)
# Node(a1.h10, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h18->a2.h7<k>, score: -0.0005631030653603375, in_graph: True)
# Node(a1.h18, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h16->a2.h7<k>, score: 0.0013270177878439426, in_graph: True)
# Node(a1.h16, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(a1.h3->a2.h7<k>, score: -0.0007349009392783046, in_graph: True)
# Node(a1.h3, in_graph: True)
# Node(a2.h7, in_graph: True)
# Edge(m1->a2.h7<q>, score: 0.006064509507268667, in_graph: True)
# Node(m1, in_graph: True)
# Node(a2.h7, in_graph: True)
# ...
# Node(a12.h2, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(m12->a15.h31<q>, score: -0.0005337204202078283, in_graph: True)
# Node(m12, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(m9->a15.h31<q>, score: -0.0013865953078493476, in_graph: True)
# Node(m9, in_graph: True)
# Node(a15.h31, in_graph: True)
# Edge(a10.h26->a15.h31<q>, score: -0.0006930104573257267, in_graph: True)
# Node(a10.h26, in_graph: True)
# Node(a15.h31, in_graph: True)
# {'a0.h0': 0.02249383257003501,
#  'a0.h1': -0.008293697377666831,
#  'a0.h2': -0.016595377295743674,
#  'a0.h3': -0.008078590326476842,
#  'a0.h4': 0.009157457039691508,
#  'a0.h5': -0.009801684529520571,
#  'a0.h6': -0.005132298218086362,
#  'a0.h7': 0.006465522106736898,
#  'a0.h8': 0.001052121282555163,
#  'a0.h9': 0.0026952028274536133,
#  'a0.h10': 0.0014006445417180657,
#  'a0.h11': -0.0010506869293749332,
#  'a0.h12': -0.002224645344540477,
#  'a0.h13': 0.0057983361184597015,
#  'a0.h14': -0.000484858377603814,
#  'a0.h15': -0.003959375433623791,
#  'a0.h16': 0.000522392860148102,
#  'a0.h17': 0.0011023316765204072,
#  'a0.h18': -0.004075650125741959,
#  'a0.h19': 0.0007447243551723659,
#  'a0.h20': -0.003921865951269865,
#  'a0.h22': 0.00457946490496397,
#  'a0.h24': -0.000793035258539021,
#  'a0.h27': -0.001701776753179729,
#  'a0.h28': 0.0011482920963317156,
#  'a0.h30': -0.00509767746552825,
#  'a1.h0': -0.003025828074896708,
#  'a1.h1': 0.0025858654407784343,
#  'a1.h2': -0.0023098314995877445,
#  'a1.h3': -0.013575639808550477,
#  'a1.h4': 0.02003953405073844,
#  'a1.h5': 0.025964751665014774,
#  'a1.h6': -0.01206560677383095,
#  'a1.h7': 0.0023527726880274713,
#  'a1.h8': 0.0009206290123984218,
#  'a1.h9': -0.003196073812432587,
#  'a1.h10': 0.008335175225511193,
#  'a1.h11': 0.005323894205503166,
#  'a1.h12': -0.0023244619369506836,
#  'a1.h13': 0.0012307486031204462,
#  'a1.h14': 0.0012242525117471814,
#  'a1.h15': 0.0006284150294959545,
#  'a1.h16': 0.0007623771671205759,
#  'a1.h17': -0.008017033571377397,
#  'a1.h18': -0.006081984145566821,
#  'a1.h19': 0.0006406396860256791,
#  'a1.h20': 0.0004905304522253573,
#  'a1.h21': -0.006121906160842627,
#  'a1.h22': -0.002873316640034318,
#  'a1.h23': 0.02168820280348882,
#  'a1.h24': -0.0017642477178014815,
#  'a1.h25': -0.020065540389623493,
#  'a1.h26': -0.0011349458945915103,
#  'a1.h27': 0.0008367321570403874,
#  'a1.h28': -0.00044288893695920706,
#  'a1.h29': -0.002922048093751073,
#  'a1.h30': -0.00337884365580976,
#  'a1.h31': 0.007825312437489629,
#  'a2.h0': -0.006486578902695328,
#  'a2.h1': -0.0014211101224645972,
#  'a2.h2': -0.011775382939958945,
#  'a2.h3': 0.0016946485557127744,
#  'a2.h4': -0.013445972377667204,
#  'a2.h5': -0.009721787384478375,
#  'a2.h6': 0.01850057573756203,
#  'a2.h7': 0.025450230226852,
#  'a2.h8': -0.0017230421071872115,
#  'a2.h9': -0.00043420406291261315,
#  'a2.h10': -0.000264025351498276,
#  'a2.h11': 0.002775535802356899,
#  'a2.h12': 0.0041293183458037674,
#  'a2.h13': 0.0038960573147051036,
#  'a2.h14': -0.0021850632911082357,
#  'a2.h15': -0.0016349921352230012,
#  'a2.h16': 0.002134930662577972,
#  'a2.h17': -0.0036981357261538506,
#  'a2.h18': -0.00446966418530792,
#  'a2.h19': -0.0011512316996231675,
#  'a2.h20': -0.004552167723886669,
#  'a2.h21': -0.001542669429909438,
#  'a2.h22': -0.0024710199213586748,
#  'a2.h23': 0.0016951982397586107,
#  'a2.h24': 0.0017711957916617393,
#  'a2.h25': -0.0032990947365760803,
#  'a2.h26': 0.01857626292621717,
#  'a2.h27': -0.010725935047958046,
#  'a2.h28': -0.0008446217980235815,
#  'a2.h29': -0.002834759186953306,
#  'a2.h30': -0.001236508833244443,
#  'a2.h31': -0.003312068758532405,
#  'a3.h0': -0.004755461355671287,
#  'a3.h1': -0.0048563120944891125,
#  'a3.h2': 0.025053591409232467,
#  'a3.h3': -0.0037924749776721,
#  'a3.h4': -0.015469002100871876,
#  'a3.h5': -0.0012822137505281717,
#  'a3.h6': -0.032607578876195475,
#  'a3.h7': -0.004979587363777682,
#  'a3.h8': -0.014330752048408613,
#  'a3.h9': 0.010326574207283556,
#  'a3.h10': -0.000988972868071869,
#  'a3.h11': -0.0013676044763997197,
#  'a3.h12': -0.0012166592641733587,
#  'a3.h13': -0.0016317414701916277,
#  'a3.h14': -0.00041685267933644354,
#  'a3.h15': 0.0038979630335234106,
#  'a3.h16': -0.0009643212542869151,
#  'a3.h17': -0.0009645146201364696,
#  'a3.h18': -0.000922666396945715,
#  'a3.h19': -0.0028658250521402806,
#  'a3.h20': -0.010114145465195179,
#  'a3.h21': 0.0025493152788840234,
#  'a3.h22': -0.007800191902788356,
#  'a3.h23': -0.0005866773426532745,
#  'a3.h24': 0.001233615999808535,
#  'a3.h25': -0.001539597229566425,
#  'a3.h26': 0.008525148034095764,
#  'a3.h27': -0.004646933259209618,
#  'a3.h28': 0.0034307625028304756,
#  'a3.h29': -0.0008953159558586776,
#  'a3.h30': 0.0030215397418942302,
#  'a3.h31': -0.00046486337669193745,
#  'a4.h0': 0.0016910723643377423,
#  'a4.h1': -0.00431939892587252,
#  'a4.h2': 0.00679173442767933,
#  'a4.h3': -0.0009673419990576804,
#  'a4.h4': -0.004107384040253237,
#  'a4.h5': -0.0038950088783167303,
#  'a4.h6': -6.200349889695644e-05,
#  'a4.h7': -0.00806591982836835,
#  'a4.h8': -0.01038885465823114,
#  'a4.h9': 0.011595815973123536,
#  'a4.h10': 0.0072169851046055555,
#  'a4.h11': 0.0009964796190615743,
#  'a4.h12': 0.0017467467114329338,
#  'a4.h13': 0.0010822144686244428,
#  'a4.h14': -0.001978690503165126,
#  'a4.h15': -0.0021279931534081697,
#  'a4.h16': 0.011985174962319434,
#  'a4.h17': -0.004076402634382248,
#  'a4.h18': 0.002930102782556787,
#  'a4.h19': -0.0013115972687955946,
#  'a4.h21': -0.0024131895625032485,
#  'a4.h22': 0.00365494706784375,
#  'a4.h23': 0.0009397834073752165,
#  'a4.h24': -0.0006983509520068765,
#  'a4.h25': 0.001233583374414593,
#  'a4.h26': -0.0005640363087877631,
#  'a4.h27': 0.0019120337965432554,
#  'a4.h28': 0.0020939346868544817,
#  'a4.h29': -0.004821962036658078,
#  'a4.h30': 0.002793345833197236,
#  'a4.h31': 0.0007579035009257495,
#  'a5.h0': -0.007879290613345802,
#  'a5.h1': 0.007502851483877748,
#  'a5.h2': 0.004061024636030197,
#  'a5.h3': -0.02319789893226698,
#  'a5.h4': -0.0035589314938988537,
#  'a5.h5': 0.0234191304189153,
#  'a5.h6': -0.012798463780200109,
#  'a5.h7': 0.0022854751150589436,
#  'a5.h8': 0.0033840167161542922,
#  'a5.h9': 0.00025825013290159404,
#  'a5.h10': 0.0006370789196807891,
#  'a5.h11': 0.003328798688016832,
#  'a5.h12': 0.008178743533790112,
#  'a5.h13': -0.003983094298746437,
#  'a5.h14': -0.0068409294472076,
#  'a5.h15': -0.0024743142421357334,
#  'a5.h16': -0.009097794361878186,
#  'a5.h17': 0.0013322274025995284,
#  'a5.h18': 0.0045403820113278925,
#  'a5.h19': -0.010220733849564567,
#  'a5.h20': -0.005789043760159984,
#  'a5.h21': 0.0022584028192795813,
#  'a5.h22': 0.0024551806855015457,
#  'a5.h23': -0.006068319460609928,
#  'a5.h24': 0.002099084173096344,
#  'a5.h25': 0.0020023231918457896,
#  'a5.h26': 0.0008374310273211449,
#  'a5.h27': 0.0020332946733105928,
#  'a5.h28': -0.008542779658455402,
#  'a5.h29': -0.004609712399542332,
#  'a5.h30': 0.00047201543929986656,
#  'a5.h31': -0.002919882826972753,
#  'a6.h0': 0.0017529666365589947,
#  'a6.h1': 0.01753368097706698,
#  'a6.h2': 0.00015502847963944077,
#  'a6.h3': -0.009090731909964234,
#  'a6.h4': 0.0065711991337593645,
#  'a6.h5': 0.011308201326755807,
#  'a6.h6': 0.011886907566804439,
#  'a6.h7': -0.011469635996036232,
#  'a6.h8': 0.003284134523710236,
#  'a6.h9': -0.0005726651579607278,
#  'a6.h10': 0.003324322897242382,
#  'a6.h11': 0.0006714470509905368,
#  'a6.h12': 0.019662600447190925,
#  'a6.h13': -0.01446887364727445,
#  'a6.h14': 0.009532605297863483,
#  'a6.h15': -0.00454724405426532,
#  'a6.h16': -0.0031846833298914135,
#  'a6.h17': 0.0005618491559289396,
#  'a6.h18': 0.0003714095801115036,
#  'a6.h19': -0.0013770211662631482,
#  'a6.h20': 0.0007229064358398318,
#  'a6.h21': -0.0008153833914548159,
#  'a6.h22': 0.0055008573399391025,
#  'a6.h23': 0.0019059710903093219,
#  'a6.h24': 0.0004040937637910247,
#  'a6.h25': -0.002076058357488364,
#  'a6.h26': 0.0013167215511202812,
#  'a6.h27': 0.0070531401433981955,
#  'a6.h28': 0.005331742198904976,
#  'a6.h29': 0.0046050552919041365,
#  'a6.h30': -0.012698224833002314,
#  'a6.h31': -0.0043983738287352026,
#  'a7.h0': 0.006089033326134086,
#  'a7.h1': 0.001828223088523373,
#  'a7.h2': 0.00801943161059171,
#  'a7.h3': 0.01218255830463022,
#  'a7.h4': -0.0017078890814445913,
#  'a7.h5': 0.014107403694652021,
#  'a7.h6': 0.002955223753815517,
#  'a7.h7': 0.003991080011473969,
#  'a7.h8': -0.0013807684881612659,
#  'a7.h9': -0.0038589491741731763,
#  'a7.h10': -0.00034574890742078424,
#  'a7.h11': -0.003479190287180245,
#  'a7.h12': 0.005078326910734177,
#  'a7.h13': -0.0002775098546408117,
#  'a7.h14': 0.00740826191031374,
#  'a7.h15': -0.004617465572664514,
#  'a7.h16': -0.0030364812701009214,
#  'a7.h17': 0.001358362496830523,
#  'a7.h18': -0.0025247129960916936,
#  'a7.h19': 0.0010695959790609777,
#  'a7.h20': -0.0016823892947286367,
#  'a7.h21': 0.0018980529566761106,
#  'a7.h22': -0.01587142382049933,
#  'a7.h23': 0.0010236822708975524,
#  'a7.h24': 0.003544436884112656,
#  'a7.h25': -0.0026252950192429125,
#  'a7.h26': 0.005387655401136726,
#  'a7.h27': -0.007611331879161298,
#  'a7.h28': -0.01652665704023093,
#  'a7.h29': 0.0015489439538214356,
#  'a7.h30': 0.0006543893832713366,
#  'a7.h31': 0.003194951976183802,
#  'a8.h0': 0.006974617106607184,
#  'a8.h1': 0.010963477805489674,
#  'a8.h2': 0.017209982412168756,
#  'a8.h3': 0.0025383844040334225,
#  'a8.h4': 3.564156941138208e-05,
#  'a8.h5': -0.002000804874114692,
#  'a8.h6': 0.02543355742818676,
#  'a8.h7': 0.004237119370372966,
#  'a8.h8': -0.0020317798480391502,
#  'a8.h9': -0.0004225039738230407,
#  'a8.h10': -0.00025316042592749,
#  'a8.h11': 0.0014641190646216273,
#  'a8.h12': -0.00391942128771916,
#  'a8.h13': 0.007595842675073072,
#  'a8.h14': 0.0026982835843227804,
#  'a8.h15': -0.00023972970666363835,
#  'a8.h16': -0.002100489044096321,
#  'a8.h17': 0.00021883833687752485,
#  'a8.h18': 0.0014616867701988667,
#  'a8.h19': 0.0022762204171158373,
#  'a8.h20': 0.004996422387193888,
#  'a8.h21': -0.0006180861382745206,
#  'a8.h22': 0.0014928880555089563,
#  'a8.h23': -0.0006388190085999668,
#  'a8.h24': 0.0039605282072443515,
#  'a8.h25': 0.002046237757895142,
#  'a8.h26': -0.0005860630189999938,
#  'a8.h27': -0.0022475288424175233,
#  'a8.h28': -0.006457136536482722,
#  'a8.h29': 0.0020414003811310977,
#  'a8.h30': 0.002644966938532889,
#  'a8.h31': 0.0012093654368072748,
#  'a9.h0': 0.003467936272500083,
#  'a9.h1': 0.011914499249542132,
#  'a9.h2': -0.0017341734492219985,
#  'a9.h3': -0.013509727461496368,
#  'a9.h4': -0.003644706914201379,
#  'a9.h5': 0.02213968866271898,
#  'a9.h6': 0.011061496683396399,
#  'a9.h7': 0.004536374966846779,
#  'a9.h8': -0.0017302098567597568,
#  'a9.h9': 0.0010493416048120707,
#  'a9.h10': 0.0002228148514404893,
#  'a9.h12': 0.0011697967420332134,
#  'a9.h13': 0.0029286534409038723,
#  'a9.h14': 0.0008175487164407969,
#  'a9.h15': -0.00030160456662997603,
#  'a9.h16': -0.0006256644264794886,
#  'a9.h17': -0.0005196376005187631,
#  'a9.h18': 0.003913351189112291,
#  'a9.h19': -0.0012449037749320269,
#  'a9.h20': -0.000254936283454299,
#  'a9.h21': -0.0007601744146086276,
#  'a9.h22': 0.0006632644799537957,
#  'a9.h23': -0.0022584835533052683,
#  'a9.h24': -0.0011748581018764526,
#  'a9.h25': -0.0004154031921643764,
#  'a9.h26': 0.0019437636365182698,
#  'a9.h27': 0.0010957523772958666,
#  'a9.h28': -0.0005544187151826918,
#  'a9.h29': -0.0032699931180104613,
#  'a9.h30': 0.0007810798124410212,
#  'a9.h31': -0.0004918834019917995,
#  'a10.h0': 0.003062309668166563,
#  'a10.h1': -0.004506927012698725,
#  'a10.h2': -0.002310075768036768,
#  'a10.h3': 0.004109950648853555,
#  'a10.h4': -0.012240247131558135,
#  'a10.h5': 0.007564169412944466,
#  'a10.h6': -0.006218237453140318,
#  'a10.h7': 0.007586448336951435,
#  'a10.h8': -0.0005739180487580597,
#  'a10.h9': -0.004048805916681886,
#  'a10.h10': -0.000652223126962781,
#  'a10.h11': 0.002988429449032992,
#  'a10.h12': -0.0027838917449116707,
#  'a10.h13': 0.00036164638004265726,
#  'a10.h14': 0.0005865786806680262,
#  'a10.h15': -0.0024673254520166665,
#  'a10.h16': -0.0025393496616743505,
#  'a10.h17': 0.0047083558165468276,
#  'a10.h18': 0.00047175318468362093,
#  'a10.h20': 0.0007088283891789615,
#  'a10.h21': 0.0028870644164271653,
#  'a10.h22': 0.0015962414327077568,
#  'a10.h23': 0.006504218094050884,
#  'a10.h24': 0.005717564665246755,
#  'a10.h25': 0.0001936222251970321,
#  'a10.h26': -0.001279943942790851,
#  'a10.h27': -0.0010653893987182528,
#  'a10.h28': 0.0005472955526784062,
#  'a10.h30': -0.0006946820067241788,
#  'a11.h0': 0.004096476215636358,
#  'a11.h2': -0.0025460850156378,
#  'a11.h3': -0.003997778636403382,
#  'a11.h4': 0.0004638259706553072,
#  'a11.h5': 0.0008817818015813828,
#  'a11.h7': 0.002267459291033447,
#  'a11.h8': 0.007118081324733794,
#  'a11.h9': 0.00011432130122557282,
#  'a11.h10': -0.0018604801152832806,
#  'a11.h11': 0.0006522141629830003,
#  'a11.h13': 0.0007476370665244758,
#  'a11.h14': 0.0027899922570213675,
#  'a11.h15': -0.00037647795397788286,
#  'a11.h16': -0.0004770686209667474,
#  'a11.h21': -0.005494270153576508,
#  'a11.h22': -0.0006515599088743329,
#  'a11.h23': -0.015916453034151345,
#  'a11.h24': 0.0002705384395085275,
#  'a11.h26': 0.0007881565252318978,
#  'a11.h27': -0.00012440132559277117,
#  'a11.h28': 5.60223706997931e-05,
#  'a11.h29': -0.001196841534692794,
#  'a11.h30': 0.002261691144667566,
#  'a11.h31': 0.0004980650264769793,
#  'a12.h0': 0.005636544723529369,
#  'a12.h1': 0.005865834711585194,
#  'a12.h2': -0.00456335986382328,
#  'a12.h3': 0.006515359244076535,
#  'a12.h4': -0.000649294990580529,
#  'a12.h5': 0.0033010928600560874,
#  'a12.h6': -0.00103903713170439,
#  'a12.h7': -0.005775135708972812,
#  'a12.h8': -0.0004488558624871075,
#  'a12.h10': 0.0004466171085368842,
#  'a12.h11': 0.0016758120036683977,
#  'a12.h13': 0.01625990547472611,
#  'a12.h14': -0.004280245746485889,
#  'a12.h15': -0.007368914521066472,
#  'a12.h16': 0.001458852580981329,
#  'a12.h17': -0.001942066301126033,
#  'a12.h18': 0.001442430861061439,
#  'a12.h19': 4.297128180041909e-05,
#  'a12.h22': -0.001147341332398355,
#  'a12.h26': -0.000585302070248872,
#  'a12.h28': -0.004432233865372837,
#  'a12.h29': 0.00016012712148949504,
#  'a13.h0': 0.0022698878310620785,
#  'a13.h1': -0.009306944906711578,
#  'a13.h2': -0.0010720927093643695,
#  'a13.h3': 0.0032289552327711135,
#  'a13.h4': -0.0033046037424355745,
#  'a13.h5': 0.005325864185579121,
#  'a13.h6': -0.006392921175574884,
#  'a13.h7': 0.001981700275791809,
#  'a13.h8': -0.001556920527946204,
#  'a13.h9': 0.0014059745008125901,
#  'a13.h11': 0.0010911193094216287,
#  'a13.h13': -0.00027227209648117423,
#  'a13.h14': 0.0004538584325928241,
#  'a13.h16': 0.0005031441105529666,
#  'a13.h17': -0.00017486108117736876,
#  'a13.h18': -0.0022168526775203645,
#  'a13.h19': 0.0003283738042227924,
#  'a13.h20': 0.0012114667624700814,
#  'a13.h21': -0.0002613101387396455,
#  'a13.h23': -0.002223517163656652,
#  'a13.h24': -3.1311967177316546e-05,
#  'a13.h25': -0.0009146403754130006,
#  'a13.h26': -0.0002908798633143306,
#  'a13.h27': 0.0022682012640871108,
#  'a13.h30': 0.0006958708399906754,
#  'a13.h31': 0.0010095703182742,
#  'a14.h1': 0.001867885555839166,
#  'a14.h2': -0.0009013416420202702,
#  'a14.h3': 0.0031684573041275144,
#  'a14.h4': -0.0011175285035278648,
#  'a14.h5': -0.0025446639338042587,
#  'a14.h6': -0.0035448049602564424,
#  'a14.h7': -0.0034990726853720844,
#  'a14.h8': 0.0005633664550259709,
#  'a14.h9': -0.001369525445625186,
#  'a14.h13': -0.004051947791595012,
#  'a14.h14': 0.003104287141468376,
#  'a14.h15': -0.0027278272318653762,
#  'a14.h16': 0.0005207228241488338,
#  'a14.h20': -0.006933304946869612,
#  'a14.h22': -0.00788536321488209,
#  'a14.h24': 0.0008622306049801409,
#  'a14.h25': -0.0005246668588370085,
#  'a14.h26': -0.0019386941858101636,
#  'a14.h27': 0.0005210801027715206,
#  'a14.h29': 0.00034633520408533514,
#  'a14.h30': -0.0028852777904830873,
#  'a14.h31': 0.0005929204053245485,
#  'a15.h0': -0.001204661966767162,
#  'a15.h1': -0.005135162646183744,
#  'a15.h2': 0.007335362228332087,
#  'a15.h3': 0.01309575661434792,
#  'a15.h5': -0.003433431003941223,
#  'a15.h6': 0.0006019395659677684,
#  'a15.h7': 0.006529702339321375,
#  'a15.h8': -0.0006250737351365387,
#  'a15.h11': -6.299873348325491e-06,
#  'a15.h12': -0.0012066254275850952,
#  'a15.h13': 0.000547451083548367,
#  'a15.h16': 0.0027913934900425375,
#  'a15.h17': 0.001379877416184172,
#  'a15.h18': 0.005059301416622475,
#  'a15.h21': -0.00047149372403509915,
#  'a15.h23': -0.001858989242464304,
#  'a15.h24': 0.0012367979506962001,
#  'a15.h27': -0.000127310398966074,
#  'a15.h28': 0.00431626004865393,
#  'a15.h29': 0.010246446065139025,
#  'a15.h30': 0.002472233842127025,
#  'a15.h31': -0.004792356165125966}

# %%
import torch

# Create a tensor to store the heatmap values
heatmap_tensor = torch.zeros((16, 32))  # Assuming a maximum of 16 layers and 32 heads

# Populate the tensor with values from heatmap_dict
for key, value in heatmap_dict.items():
    layer, head = map(int, key[1:].split('.h'))
    heatmap_tensor[layer, head] = value

heatmap_tensor
# Out:
# tensor([[ 2.2494e-02, -8.2937e-03, -1.6595e-02, -8.0786e-03,  9.1575e-03,
#          -9.8017e-03, -5.1323e-03,  6.4655e-03,  1.0521e-03,  2.6952e-03,
#           1.4006e-03, -1.0507e-03, -2.2246e-03,  5.7983e-03, -4.8486e-04,
#          -3.9594e-03,  5.2239e-04,  1.1023e-03, -4.0757e-03,  7.4472e-04,
#          -3.9219e-03,  0.0000e+00,  4.5795e-03,  0.0000e+00, -7.9304e-04,
#           0.0000e+00,  0.0000e+00, -1.7018e-03,  1.1483e-03,  0.0000e+00,
#          -5.0977e-03,  0.0000e+00],
#         [-3.0258e-03,  2.5859e-03, -2.3098e-03, -1.3576e-02,  2.0040e-02,
#           2.5965e-02, -1.2066e-02,  2.3528e-03,  9.2063e-04, -3.1961e-03,
#           8.3352e-03,  5.3239e-03, -2.3245e-03,  1.2307e-03,  1.2243e-03,
#           6.2842e-04,  7.6238e-04, -8.0170e-03, -6.0820e-03,  6.4064e-04,
#           4.9053e-04, -6.1219e-03, -2.8733e-03,  2.1688e-02, -1.7642e-03,
#          -2.0066e-02, -1.1349e-03,  8.3673e-04, -4.4289e-04, -2.9220e-03,
#          -3.3788e-03,  7.8253e-03],
#         [-6.4866e-03, -1.4211e-03, -1.1775e-02,  1.6946e-03, -1.3446e-02,
#          -9.7218e-03,  1.8501e-02,  2.5450e-02, -1.7230e-03, -4.3420e-04,
#          -2.6403e-04,  2.7755e-03,  4.1293e-03,  3.8961e-03, -2.1851e-03,
#          -1.6350e-03,  2.1349e-03, -3.6981e-03, -4.4697e-03, -1.1512e-03,
#          -4.5522e-03, -1.5427e-03, -2.4710e-03,  1.6952e-03,  1.7712e-03,
#          -3.2991e-03,  1.8576e-02, -1.0726e-02, -8.4462e-04, -2.8348e-03,
#          -1.2365e-03, -3.3121e-03],
#         [-4.7555e-03, -4.8563e-03,  2.5054e-02, -3.7925e-03, -1.5469e-02,
#          -1.2822e-03, -3.2608e-02, -4.9796e-03, -1.4331e-02,  1.0327e-02,
#          -9.8897e-04, -1.3676e-03, -1.2167e-03, -1.6317e-03, -4.1685e-04,
#           3.8980e-03, -9.6432e-04, -9.6451e-04, -9.2267e-04, -2.8658e-03,
#          -1.0114e-02,  2.5493e-03, -7.8002e-03, -5.8668e-04,  1.2336e-03,
#          -1.5396e-03,  8.5251e-03, -4.6469e-03,  3.4308e-03, -8.9532e-04,
#           3.0215e-03, -4.6486e-04],
#         [ 1.6911e-03, -4.3194e-03,  6.7917e-03, -9.6734e-04, -4.1074e-03,
#          -3.8950e-03, -6.2003e-05, -8.0659e-03, -1.0389e-02,  1.1596e-02,
#           7.2170e-03,  9.9648e-04,  1.7467e-03,  1.0822e-03, -1.9787e-03,
#          -2.1280e-03,  1.1985e-02, -4.0764e-03,  2.9301e-03, -1.3116e-03,
#           0.0000e+00, -2.4132e-03,  3.6549e-03,  9.3978e-04, -6.9835e-04,
#           1.2336e-03, -5.6404e-04,  1.9120e-03,  2.0939e-03, -4.8220e-03,
#           2.7933e-03,  7.5790e-04],
#         [-7.8793e-03,  7.5029e-03,  4.0610e-03, -2.3198e-02, -3.5589e-03,
#           2.3419e-02, -1.2798e-02,  2.2855e-03,  3.3840e-03,  2.5825e-04,
#           6.3708e-04,  3.3288e-03,  8.1787e-03, -3.9831e-03, -6.8409e-03,
#          -2.4743e-03, -9.0978e-03,  1.3322e-03,  4.5404e-03, -1.0221e-02,
#          -5.7890e-03,  2.2584e-03,  2.4552e-03, -6.0683e-03,  2.0991e-03,
#           2.0023e-03,  8.3743e-04,  2.0333e-03, -8.5428e-03, -4.6097e-03,
#           4.7202e-04, -2.9199e-03],
#         [ 1.7530e-03,  1.7534e-02,  1.5503e-04, -9.0907e-03,  6.5712e-03,
#           1.1308e-02,  1.1887e-02, -1.1470e-02,  3.2841e-03, -5.7267e-04,
#           3.3243e-03,  6.7145e-04,  1.9663e-02, -1.4469e-02,  9.5326e-03,
#          -4.5472e-03, -3.1847e-03,  5.6185e-04,  3.7141e-04, -1.3770e-03,
#           7.2291e-04, -8.1538e-04,  5.5009e-03,  1.9060e-03,  4.0409e-04,
#          -2.0761e-03,  1.3167e-03,  7.0531e-03,  5.3317e-03,  4.6051e-03,
#          -1.2698e-02, -4.3984e-03],
#         [ 6.0890e-03,  1.8282e-03,  8.0194e-03,  1.2183e-02, -1.7079e-03,
#           1.4107e-02,  2.9552e-03,  3.9911e-03, -1.3808e-03, -3.8589e-03,
#          -3.4575e-04, -3.4792e-03,  5.0783e-03, -2.7751e-04,  7.4083e-03,
#          -4.6175e-03, -3.0365e-03,  1.3584e-03, -2.5247e-03,  1.0696e-03,
#          -1.6824e-03,  1.8981e-03, -1.5871e-02,  1.0237e-03,  3.5444e-03,
#          -2.6253e-03,  5.3877e-03, -7.6113e-03, -1.6527e-02,  1.5489e-03,
#           6.5439e-04,  3.1950e-03],
#         [ 6.9746e-03,  1.0963e-02,  1.7210e-02,  2.5384e-03,  3.5642e-05,
#          -2.0008e-03,  2.5434e-02,  4.2371e-03, -2.0318e-03, -4.2250e-04,
#          -2.5316e-04,  1.4641e-03, -3.9194e-03,  7.5958e-03,  2.6983e-03,
#          -2.3973e-04, -2.1005e-03,  2.1884e-04,  1.4617e-03,  2.2762e-03,
#           4.9964e-03, -6.1809e-04,  1.4929e-03, -6.3882e-04,  3.9605e-03,
#           2.0462e-03, -5.8606e-04, -2.2475e-03, -6.4571e-03,  2.0414e-03,
#           2.6450e-03,  1.2094e-03],
#         [ 3.4679e-03,  1.1914e-02, -1.7342e-03, -1.3510e-02, -3.6447e-03,
#           2.2140e-02,  1.1061e-02,  4.5364e-03, -1.7302e-03,  1.0493e-03,
#           2.2281e-04,  0.0000e+00,  1.1698e-03,  2.9287e-03,  8.1755e-04,
#          -3.0160e-04, -6.2566e-04, -5.1964e-04,  3.9134e-03, -1.2449e-03,
#          -2.5494e-04, -7.6017e-04,  6.6326e-04, -2.2585e-03, -1.1749e-03,
#          -4.1540e-04,  1.9438e-03,  1.0958e-03, -5.5442e-04, -3.2700e-03,
#           7.8108e-04, -4.9188e-04],
#         [ 3.0623e-03, -4.5069e-03, -2.3101e-03,  4.1100e-03, -1.2240e-02,
#           7.5642e-03, -6.2182e-03,  7.5864e-03, -5.7392e-04, -4.0488e-03,
#          -6.5222e-04,  2.9884e-03, -2.7839e-03,  3.6165e-04,  5.8658e-04,
#          -2.4673e-03, -2.5393e-03,  4.7084e-03,  4.7175e-04,  0.0000e+00,
#           7.0883e-04,  2.8871e-03,  1.5962e-03,  6.5042e-03,  5.7176e-03,
#           1.9362e-04, -1.2799e-03, -1.0654e-03,  5.4730e-04,  0.0000e+00,
#          -6.9468e-04,  0.0000e+00],
#         [ 4.0965e-03,  0.0000e+00, -2.5461e-03, -3.9978e-03,  4.6383e-04,
#           8.8178e-04,  0.0000e+00,  2.2675e-03,  7.1181e-03,  1.1432e-04,
#          -1.8605e-03,  6.5221e-04,  0.0000e+00,  7.4764e-04,  2.7900e-03,
#          -3.7648e-04, -4.7707e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00, -5.4943e-03, -6.5156e-04, -1.5916e-02,  2.7054e-04,
#           0.0000e+00,  7.8816e-04, -1.2440e-04,  5.6022e-05, -1.1968e-03,
#           2.2617e-03,  4.9807e-04],
#         [ 5.6365e-03,  5.8658e-03, -4.5634e-03,  6.5154e-03, -6.4929e-04,
#           3.3011e-03, -1.0390e-03, -5.7751e-03, -4.4886e-04,  0.0000e+00,
#           4.4662e-04,  1.6758e-03,  0.0000e+00,  1.6260e-02, -4.2802e-03,
#          -7.3689e-03,  1.4589e-03, -1.9421e-03,  1.4424e-03,  4.2971e-05,
#           0.0000e+00,  0.0000e+00, -1.1473e-03,  0.0000e+00,  0.0000e+00,
#           0.0000e+00, -5.8530e-04,  0.0000e+00, -4.4322e-03,  1.6013e-04,
#           0.0000e+00,  0.0000e+00],
#         [ 2.2699e-03, -9.3069e-03, -1.0721e-03,  3.2290e-03, -3.3046e-03,
#           5.3259e-03, -6.3929e-03,  1.9817e-03, -1.5569e-03,  1.4060e-03,
#           0.0000e+00,  1.0911e-03,  0.0000e+00, -2.7227e-04,  4.5386e-04,
#           0.0000e+00,  5.0314e-04, -1.7486e-04, -2.2169e-03,  3.2837e-04,
#           1.2115e-03, -2.6131e-04,  0.0000e+00, -2.2235e-03, -3.1312e-05,
#          -9.1464e-04, -2.9088e-04,  2.2682e-03,  0.0000e+00,  0.0000e+00,
#           6.9587e-04,  1.0096e-03],
#         [ 0.0000e+00,  1.8679e-03, -9.0134e-04,  3.1685e-03, -1.1175e-03,
#          -2.5447e-03, -3.5448e-03, -3.4991e-03,  5.6337e-04, -1.3695e-03,
#           0.0000e+00,  0.0000e+00,  0.0000e+00, -4.0519e-03,  3.1043e-03,
#          -2.7278e-03,  5.2072e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          -6.9333e-03,  0.0000e+00, -7.8854e-03,  0.0000e+00,  8.6223e-04,
#          -5.2467e-04, -1.9387e-03,  5.2108e-04,  0.0000e+00,  3.4634e-04,
#          -2.8853e-03,  5.9292e-04],
#         [-1.2047e-03, -5.1352e-03,  7.3354e-03,  1.3096e-02,  0.0000e+00,
#          -3.4334e-03,  6.0194e-04,  6.5297e-03, -6.2507e-04,  0.0000e+00,
#           0.0000e+00, -6.2999e-06, -1.2066e-03,  5.4745e-04,  0.0000e+00,
#           0.0000e+00,  2.7914e-03,  1.3799e-03,  5.0593e-03,  0.0000e+00,
#           0.0000e+00, -4.7149e-04,  0.0000e+00, -1.8590e-03,  1.2368e-03,
#           0.0000e+00,  0.0000e+00, -1.2731e-04,  4.3163e-03,  1.0246e-02,
#           2.4722e-03, -4.7924e-03]])

# %%
import torch
import plotly.graph_objects as go
from plotly.subplots import make_subplots

tensor1 = act_patching_tensor
tensor2 = heatmap_tensor

fig = make_subplots(
    rows=1, cols=2,
    horizontal_spacing=0.05, 
    subplot_titles=("", ""),
)

# Left heatmap
fig.add_trace(
    go.Heatmap(
        z=tensor1.numpy(),
        colorscale="RdBu",
        zmid=0,
        showscale=True,
        colorbar=dict(
            title="",
            thickness=20,
            # Position the left colorbar a bit to the right of the left domain
            x=0.46,        # 0 = far left, 1 = far right
            xanchor="left"
        ),
    ),
    row=1, col=1
)

# Right heatmap
fig.add_trace(
    go.Heatmap(
        z=tensor2.numpy(),
        colorscale="RdBu",
        zmid=0,
        showscale=True,
        colorbar=dict(
            title="",
            thickness=20,
            # Place the right colorbar well to the right
            x=1.01,
            xanchor="left"
        ),
    ),
    row=1, col=2
)

# -- Make the left subplot narrower and shifted left
fig.update_xaxes(domain=[0.0, 0.45], row=1, col=1)  # 30% of total width
# -- Shift the right subplot further right
fig.update_xaxes(domain=[0.55, 1.0], row=1, col=2) # starts at 0.45, ends at 0.8

fig.update_yaxes(title_text="Layer", row=1, col=1)
fig.update_yaxes(title_text="Layer", row=1, col=2)
fig.update_xaxes(title_text="Head", row=1, col=1)
fig.update_xaxes(title_text="Head", row=1, col=2)
fig.update_yaxes(autorange="reversed", row=1, col=1)
fig.update_yaxes(autorange="reversed", row=1, col=2)

fig.update_layout(
    width=1500,                # <--- Force a smaller figure width in pixels
    height=500,
    font=dict(size=14)
)
fig.show()

# %%
fig.write_image("toxicity_heatmap.svg")

# %% [markdown]
# # Debiasing graphs

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.graph import Graph
import pandas as pd

# %%
toxicity_graph_path = "./toxicity_EAP_step12000_11853edges.json"
bias_graph_path = "./full_adv_bias_EAP-IG_step3000_2357edges.json"

toxicity_graph = Graph.from_json(toxicity_graph_path)
bias_graph = Graph.from_json(bias_graph_path)
ablated_bias = Graph.from_json(bias_graph_path)

num_edges = 0
for node_str in bias_graph.nodes:
    toxicity_node = toxicity_graph.nodes[node_str]
    bias_node = bias_graph.nodes[node_str]
    ablated_bias_node = ablated_bias.nodes[node_str]
    
    for bias_edge, toxicity_edge, ablated_bias_edge in zip(bias_node.parent_edges, toxicity_node.parent_edges, ablated_bias_node.parent_edges):
        assert bias_edge.name == toxicity_edge.name == ablated_bias_edge.name
        # keeping edge in bias and not in toxicity
        if bias_edge.in_graph and toxicity_edge.in_graph:
            num_edges += 1
            ablated_bias_edge.in_graph = False

print("number of common edges", num_edges)
total_edges = 0
for node_str in ablated_bias.nodes:
    node = ablated_bias.nodes[node_str]
    for p_edge in node.parent_edges:
        if p_edge.in_graph:
            total_edges += 1
print("number of edges in bias circuit after turning off common", total_edges)

# %%
ablated_bias.to_json("./ablated_bias_EAP-IG_step3000_2357edges_with_toxicity_EAP_step12000_11853edges.json")

# %%
# turn all edges in bias circuit off to create empty graph
false_bias = Graph.from_json(bias_graph_path)
num_edges = 0
for node_str in bias_graph.nodes:
    toxicity_node = toxicity_graph.nodes[node_str]
    bias_node = bias_graph.nodes[node_str]
    ablated_bias_node = false_bias.nodes[node_str]
    
    for bias_edge, toxicity_edge, ablated_bias_edge in zip(bias_node.parent_edges, toxicity_node.parent_edges, ablated_bias_node.parent_edges):
        assert bias_edge.name == toxicity_edge.name == ablated_bias_edge.name
        num_edges += 1
        ablated_bias_edge.in_graph = False

false_bias.to_json("./no_edges_bias.json")
